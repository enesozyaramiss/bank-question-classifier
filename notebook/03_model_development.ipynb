# %% [markdown]
# # Model Development for Banking Customer Questions Classification

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.utils.class_weight import compute_class_weight, compute_sample_weight
from sklearn.model_selection import cross_val_score
import joblib
import warnings
warnings.filterwarnings('ignore')

# Set style for plots
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")

# %% [markdown]
# ## 1. DATA LOADING & EXPLORATION

# %%
# Load preprocessed data
print("Loading preprocessed data...")
train_df = pd.read_csv('../data/processed/train_data.csv', encoding='utf-8')
test_df = pd.read_csv('../data/processed/test_data.csv', encoding='utf-8')
class_mapping = pd.read_csv('../data/processed/class_mapping.csv', encoding='utf-8')

print(f"Data loaded successfully!")
print(f"   Training set: {len(train_df)} questions")
print(f"   Test set: {len(test_df)} questions") 
print(f"   Total classes: {train_df['department_target'].nunique()}")

# Extract features and targets
X_train_text = train_df['question_cleaned']
y_train = train_df['department_target']
X_test_text = test_df['question_cleaned']
y_test = test_df['department_target']

# Display class distribution
print(f"\nTraining set class distribution:")
class_dist = y_train.value_counts()
for i, (class_name, count) in enumerate(class_dist.items(), 1):
    percentage = (count / len(y_train)) * 100
    print(f"{i:2d}. {class_name[:35]:<35} {count:4d} ({percentage:5.1f}%)")

# Calculate class imbalance metrics
largest_class = class_dist.max()
smallest_class = class_dist.min()
imbalance_ratio = largest_class / smallest_class

print(f"\nClass imbalance analysis:")
print(f"   Largest class: {largest_class} samples ({(largest_class/len(y_train)*100):.1f}%)")
print(f"   Smallest class: {smallest_class} samples ({(smallest_class/len(y_train)*100):.1f}%)")
print(f"   Imbalance ratio: {imbalance_ratio:.1f}:1")
print(f"   Challenge level: {'High' if imbalance_ratio > 10 else 'Medium' if imbalance_ratio > 5 else 'Low'}")
# Out:
# Loading preprocessed data...
# Data loaded successfully!
#    Training set: 1565 questions
#    Test set: 392 questions
#    Total classes: 13
#
# Training set class distribution:
#  1. Пазар Ежедневно банкиране            458 ( 29.3%)
#  2. Други                                254 ( 16.2%)
#  3. Пазар Жилищни и ипотечни кредити     215 ( 13.7%)
#  4. Пазар Потребителско кредитиране      115 (  7.3%)
#  5. Пазар Разсрочени плащания             96 (  6.1%)
#  6. Пазар Малък бизнес                    76 (  4.9%)
#  7. ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ             66 (  4.2%)
#  8. Пазар Спестяване и инвестиции         66 (  4.2%)
#  9. Няколко пазара                        56 (  3.6%)
# 10. Пазар Банково застраховане            53 (  3.4%)
# 11. ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ   49 (  3.1%)
# 12. Support_Services                      35 (  2.2%)
# 13. ДИРЕКЦИЯ КРЕДИТЕН РИСК ИНДИВИДУАЛНИ   26 (  1.7%)
#
# Class imbalance analysis:
#    Largest class: 458 samples (29.3%)
#    Smallest class: 26 samples (1.7%)
#    Imbalance ratio: 17.6:1
#    Challenge level: High

# %% [markdown]
# ## 2. FEATURE ENGINEERING - TF-IDF VECTORIZATION

# %%
print("TF-IDF configuration for Bulgarian text:")

# Configure TF-IDF for Bulgarian text
vectorizer = TfidfVectorizer(
    max_features=5000,          # Reasonable feature count for dataset size
    ngram_range=(1, 2),         # Unigrams and bigrams for context
    min_df=2,                   # Ignore terms that appear in less than 2 documents
    max_df=0.95,                # Ignore terms that appear in more than 95% of documents
    strip_accents='unicode',    # Handle accented characters
    lowercase=True,             # Normalize case
    token_pattern=r'\b\w+\b'    # Word boundaries for proper tokenization
)

print(f"   Max features: {vectorizer.max_features}")
print(f"   N-gram range: {vectorizer.ngram_range}")
print(f"   Min document frequency: {vectorizer.min_df}")
print(f"   Max document frequency: {vectorizer.max_df}")

# Fit and transform training data
print(f"\nFitting TF-IDF vectorizer on training data...")
X_train_tfidf = vectorizer.fit_transform(X_train_text)
X_test_tfidf = vectorizer.transform(X_test_text)

print(f"TF-IDF vectorization completed!")
print(f"   Training matrix shape: {X_train_tfidf.shape}")
print(f"   Test matrix shape: {X_test_tfidf.shape}")
print(f"   Vocabulary size: {len(vectorizer.vocabulary_)}")
print(f"   Sparsity: {(1.0 - X_train_tfidf.nnz / (X_train_tfidf.shape[0] * X_train_tfidf.shape[1]))*100:.1f}%")

# Display most important features
feature_names = vectorizer.get_feature_names_out()
print(f"\nSample vocabulary (first 20 features):")
print(f"   {list(feature_names[:20])}")
# Out:
# TF-IDF configuration for Bulgarian text:
#    Max features: 5000
#    N-gram range: (1, 2)
#    Min document frequency: 2
#    Max document frequency: 0.95
#
# Fitting TF-IDF vectorizer on training data...
# TF-IDF vectorization completed!
#    Training matrix shape: (1565, 3198)
#    Test matrix shape: (392, 3198)
#    Vocabulary size: 3198
#    Sparsity: 99.6%
#
# Sample vocabulary (first 20 features):
#    ['00', '000', '000 лв', '000 лева', '000евро', '000евро 10', '000лв', '000лв за', '01', '01 06', '03', '06', '1', '1 2', '10', '10 139', '10 лева', '100', '100 000', '1000']

# %% [markdown]
# ## 3. BASELINE MODEL - LOGISTIC REGRESSION

# %%
print("Training baseline Logistic Regression model...")

# Calculate class weights to handle imbalance
class_weights = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
class_weight_dict = dict(zip(np.unique(y_train), class_weights))

print(f"Class weights for imbalance handling:")
for class_name, weight in sorted(class_weight_dict.items(), key=lambda x: x[1], reverse=True)[:5]:
    print(f"   {class_name[:30]:<30} weight: {weight:.2f}")
print(f"   ... (showing top 5)")

# Train baseline model
baseline_model = LogisticRegression(
    class_weight='balanced',
    max_iter=1000,
    random_state=42,
    solver='liblinear'  # Good for small to medium datasets
)

print(f"\nTraining baseline model...")
baseline_model.fit(X_train_tfidf, y_train)

# Make predictions
y_train_pred_baseline = baseline_model.predict(X_train_tfidf)
y_test_pred_baseline = baseline_model.predict(X_test_tfidf)

# Calculate accuracy scores
train_accuracy_baseline = accuracy_score(y_train, y_train_pred_baseline)
test_accuracy_baseline = accuracy_score(y_test, y_test_pred_baseline)

print(f"Baseline model training completed!")
print(f"   Training accuracy: {train_accuracy_baseline:.4f}")
print(f"   Test accuracy: {test_accuracy_baseline:.4f}")
print(f"   Overfitting check: {abs(train_accuracy_baseline - test_accuracy_baseline):.4f} difference")

# Cross-validation for more robust evaluation
cv_scores = cross_val_score(baseline_model, X_train_tfidf, y_train, cv=5, scoring='accuracy')
print(f"   Cross-validation accuracy: {cv_scores.mean():.4f} (±{cv_scores.std()*2:.4f})")
# Out:
# Training baseline Logistic Regression model...
# Class weights for imbalance handling:
#    ДИРЕКЦИЯ КРЕДИТЕН РИСК ИНДИВИД weight: 4.63
#    Support_Services               weight: 3.44
#    ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕ weight: 2.46
#    Пазар Банково застраховане     weight: 2.27
#    Няколко пазара                 weight: 2.15
#    ... (showing top 5)
#
# Training baseline model...
# Baseline model training completed!
#    Training accuracy: 0.8843
#    Test accuracy: 0.6888
#    Overfitting check: 0.1956 difference
#    Cross-validation accuracy: 0.6671 (±0.0260)

# %% [markdown]
# ## 4. MODEL COMPARISON - MULTIPLE ALGORITHMS

# %%
print("Training multiple models for comparison...")

# Define models to compare - focused on sklearn models that handle string labels well
models = {
    'Logistic Regression': LogisticRegression(
        class_weight='balanced', 
        max_iter=1000, 
        random_state=42,
        solver='liblinear'
    ),
    'Random Forest': RandomForestClassifier(
        n_estimators=100,
        class_weight='balanced',
        random_state=42,
        n_jobs=-1,
        max_depth=10  # Prevent overfitting
    ),
    'Naive Bayes': MultinomialNB(
        alpha=1.0  # Smoothing parameter
    ),
    'SVM (Linear)': SVC(
        kernel='linear',
        class_weight='balanced',
        random_state=42,
        probability=True,  # Enable probability estimates
        C=1.0  # Regularization
    ),
    'Extra Trees': ExtraTreesClassifier(
        n_estimators=100,
        class_weight='balanced',
        random_state=42,
        n_jobs=-1,
        max_depth=8
    ),
    'SVM (RBF)': SVC(
        kernel='rbf',
        class_weight='balanced',
        random_state=42,
        probability=True,
        C=1.0,
        gamma='scale'
    )
}

# Add Extra Trees to imports at the top
from sklearn.ensemble import ExtraTreesClassifier

# Train and evaluate each model
model_results = {}
trained_models = {}

for model_name, model in models.items():
    print(f"\nTraining {model_name}...")
    
    try:
        # Train model - all sklearn models handle string labels automatically
        model.fit(X_train_tfidf, y_train)
        
        # Make predictions
        y_train_pred = model.predict(X_train_tfidf)
        y_test_pred = model.predict(X_test_tfidf)
        
        # Calculate metrics
        train_acc = accuracy_score(y_train, y_train_pred)
        test_acc = accuracy_score(y_test, y_test_pred)
        
        # Cross-validation
        cv_scores = cross_val_score(model, X_train_tfidf, y_train, cv=5, scoring='accuracy')
        
        # Store results
        model_results[model_name] = {
            'train_accuracy': train_acc,
            'test_accuracy': test_acc,
            'cv_mean': cv_scores.mean(),
            'cv_std': cv_scores.std(),
            'overfitting': abs(train_acc - test_acc)
        }
        
        # Store trained model
        trained_models[model_name] = model
        
        print(f"   {model_name}: Test accuracy = {test_acc:.4f}, CV = {cv_scores.mean():.4f} (±{cv_scores.std()*2:.4f})")
        
    except Exception as e:
        print(f"   {model_name} failed: {str(e)}")
        continue

# Display comparison results
print(f"\nMODEL COMPARISON RESULTS:")
print(f"{'Model':<20} {'Train Acc':<10} {'Test Acc':<10} {'CV Mean':<10} {'CV Std':<10} {'Overfitting':<12}")
print("-" * 80)

for model_name, results in model_results.items():
    print(f"{model_name:<20} {results['train_accuracy']:<10.4f} {results['test_accuracy']:<10.4f} "
          f"{results['cv_mean']:<10.4f} {results['cv_std']:<10.4f} {results['overfitting']:<12.4f}")

# Select best model based on test accuracy and cross-validation
best_model_name = max(model_results.keys(), key=lambda x: model_results[x]['cv_mean'])
best_model = trained_models[best_model_name]

print(f"\nBest performing model: {best_model_name}")
print(f"   • Cross-validation accuracy: {model_results[best_model_name]['cv_mean']:.4f}")
print(f"   • Test accuracy: {model_results[best_model_name]['test_accuracy']:.4f}")
# Out:
# Training multiple models for comparison...
#
# Training Logistic Regression...
#    Logistic Regression: Test accuracy = 0.6888, CV = 0.6671 (±0.0260)
#
# Training Random Forest...
#    Random Forest: Test accuracy = 0.5408, CV = 0.5361 (±0.0792)
#
# Training Naive Bayes...
#    Naive Bayes: Test accuracy = 0.5000, CV = 0.4690 (±0.0240)
#
# Training SVM (Linear)...
#    SVM (Linear): Test accuracy = 0.6837, CV = 0.6294 (±0.0379)
#
# Training Extra Trees...
#    Extra Trees: Test accuracy = 0.5459, CV = 0.5380 (±0.0405)
#
# Training SVM (RBF)...
#    SVM (RBF): Test accuracy = 0.6709, CV = 0.6070 (±0.0692)
#
# MODEL COMPARISON RESULTS:
# Model                Train Acc  Test Acc   CV Mean    CV Std     Overfitting
# --------------------------------------------------------------------------------
# Logistic Regression  0.8843     0.6888     0.6671     0.0130     0.1956
# Random Forest        0.7125     0.5408     0.5361     0.0396     0.1716
# Naive Bayes          0.6115     0.5000     0.4690     0.0120     0.1115
# SVM (Linear)         0.9010     0.6837     0.6294     0.0190     0.2173
# Extra Trees          0.6837     0.5459     0.5380     0.0203     0.1378
# SVM (RBF)            0.9572     0.6709     0.6070     0.0346     0.2863
#
# Best performing model: Logistic Regression
#    • Cross-validation accuracy: 0.6671
#    • Test accuracy: 0.6888

# %% [markdown]
# ## 5. HYPERPARAMETER TUNING - TOP MODELS

# %%
# Select top 3 models for hyperparameter tuning
top_models = sorted(model_results.items(), key=lambda x: x[1]['cv_mean'], reverse=True)[:3]
print(f"Tuning hyperparameters for top 3 models:")
for i, (name, results) in enumerate(top_models, 1):
    print(f"   {i}. {name}: {results['cv_mean']:.4f} CV accuracy")

# Import grid search
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
import warnings
warnings.filterwarnings('ignore')

# Store tuning results
tuned_models = {}
tuning_results = {}

for model_name, _ in top_models:
    print(f"\nHyperparameter tuning for {model_name}...")
    
    base_model = models[model_name]
    
    # Define parameter grids for different models
    if model_name == 'Logistic Regression':
        param_grid = {
            'C': [0.1, 0.5, 1.0, 2.0, 5.0],
            'solver': ['liblinear', 'saga'],
            'penalty': ['l1', 'l2'],
            'max_iter': [1000, 2000]
        }
        search_method = 'grid'
        
    elif model_name == 'SVM (Linear)':
        param_grid = {
            'C': [0.1, 0.5, 1.0, 2.0, 5.0, 10.0],
            'penalty': ['l1', 'l2'],
            'loss': ['hinge', 'squared_hinge'],
            'dual': [True, False]
        }
        # Use LinearSVC for faster tuning
        from sklearn.svm import LinearSVC
        base_model = LinearSVC(class_weight='balanced', random_state=42, max_iter=2000)
        search_method = 'grid'
        
    elif model_name == 'SVM (RBF)':
        param_grid = {
            'C': [0.1, 1.0, 10.0],
            'gamma': ['scale', 'auto', 0.001, 0.01, 0.1],
            'kernel': ['rbf']
        }
        search_method = 'grid'
        
    elif 'Random Forest' in model_name or 'Extra Trees' in model_name:
        param_grid = {
            'n_estimators': [50, 100, 200],
            'max_depth': [5, 10, 15, None],
            'min_samples_split': [2, 5, 10],
            'min_samples_leaf': [1, 2, 4],
            'max_features': ['sqrt', 'log2', None]
        }
        search_method = 'random'  # Too many combinations for grid
        
    elif 'Naive Bayes' in model_name:
        param_grid = {
            'alpha': [0.1, 0.5, 1.0, 1.5, 2.0],
            'fit_prior': [True, False]
        }
        search_method = 'grid'
    
    else:
        print(f"   No parameter grid defined for {model_name}, skipping...")
        continue
    
    # Perform hyperparameter search
    try:
        if search_method == 'grid':
            search = GridSearchCV(
                base_model,
                param_grid,
                cv=5,
                scoring='accuracy',
                n_jobs=-1,
                verbose=0
            )
        else:  # random search
            search = RandomizedSearchCV(
                base_model,
                param_grid,
                n_iter=20,  # Limited iterations for speed
                cv=5,
                scoring='accuracy',
                n_jobs=-1,
                random_state=42,
                verbose=0
            )
        
        # Fit the search
        search.fit(X_train_tfidf, y_train)
        
        # Get best model
        best_tuned_model = search.best_estimator_
        
        # Evaluate on test set
        y_test_pred_tuned = best_tuned_model.predict(X_test_tfidf)
        test_acc_tuned = accuracy_score(y_test, y_test_pred_tuned)
        
        # Store results
        tuned_models[model_name] = best_tuned_model
        tuning_results[model_name] = {
            'best_params': search.best_params_,
            'best_cv_score': search.best_score_,
            'test_accuracy': test_acc_tuned,
            'original_cv': model_results[model_name]['cv_mean'],
            'original_test': model_results[model_name]['test_accuracy'],
            'cv_improvement': search.best_score_ - model_results[model_name]['cv_mean'],
            'test_improvement': test_acc_tuned - model_results[model_name]['test_accuracy']
        }
        
        print(f"   Tuning completed!")
        print(f"      Best CV score: {search.best_score_:.4f} (improvement: {tuning_results[model_name]['cv_improvement']:+.4f})")
        print(f"      Test accuracy: {test_acc_tuned:.4f} (improvement: {tuning_results[model_name]['test_improvement']:+.4f})")
        print(f"      Best parameters: {search.best_params_}")
        
    except Exception as e:
        print(f"   Tuning failed for {model_name}: {str(e)}")
        continue

# Display tuning summary
if tuning_results:
    print(f"\nHYPERPARAMETER TUNING SUMMARY:")
    print(f"{'Model':<20} {'Original CV':<12} {'Tuned CV':<12} {'CV Improve':<12} {'Original Test':<14} {'Tuned Test':<12} {'Test Improve'}")
    print("-" * 105)
    
    for model_name, results in tuning_results.items():
        print(f"{model_name:<20} {results['original_cv']:<12.4f} {results['best_cv_score']:<12.4f} "
              f"{results['cv_improvement']:<12.4f} {results['original_test']:<14.4f} "
              f"{results['test_accuracy']:<12.4f} {results['test_improvement']:<12.4f}")
    
    # Find overall best model after tuning
    best_tuned_model_name = max(tuning_results.keys(), key=lambda x: tuning_results[x]['best_cv_score'])
    final_best_model = tuned_models[best_tuned_model_name]
    
    print(f"\nFINAL BEST MODEL AFTER TUNING: {best_tuned_model_name}")
    print(f"   Tuned CV accuracy: {tuning_results[best_tuned_model_name]['best_cv_score']:.4f}")
    print(f"   Tuned test accuracy: {tuning_results[best_tuned_model_name]['test_accuracy']:.4f}")
    print(f"   Best parameters: {tuning_results[best_tuned_model_name]['best_params']}")
    
    # Update best model for final evaluation
    best_model = final_best_model
    best_model_name = best_tuned_model_name

else:
    print(f"\nNo successful hyperparameter tuning completed.")
# Out:
# Tuning hyperparameters for top 3 models:
#    1. Logistic Regression: 0.6671 CV accuracy
#    2. SVM (Linear): 0.6294 CV accuracy
#    3. SVM (RBF): 0.6070 CV accuracy
#
# Hyperparameter tuning for Logistic Regression...
#    Tuning completed!
#       Best CV score: 0.6786 (improvement: +0.0115)
#       Test accuracy: 0.6964 (improvement: +0.0077)
#       Best parameters: {'C': 5.0, 'max_iter': 1000, 'penalty': 'l2', 'solver': 'liblinear'}
#
# Hyperparameter tuning for SVM (Linear)...
#    Tuning completed!
#       Best CV score: 0.6754 (improvement: +0.0460)
#       Test accuracy: 0.6913 (improvement: +0.0077)
#       Best parameters: {'C': 1.0, 'dual': True, 'loss': 'squared_hinge', 'penalty': 'l2'}
#
# Hyperparameter tuning for SVM (RBF)...
#    Tuning completed!
#       Best CV score: 0.6415 (improvement: +0.0345)
#       Test accuracy: 0.6913 (improvement: +0.0204)
#       Best parameters: {'C': 10.0, 'gamma': 0.1, 'kernel': 'rbf'}
#
# HYPERPARAMETER TUNING SUMMARY:
# Model                Original CV  Tuned CV     CV Improve   Original Test  Tuned Test   Test Improve
# ---------------------------------------------------------------------------------------------------------
# Logistic Regression  0.6671       0.6786       0.0115       0.6888         0.6964       0.0077
# SVM (Linear)         0.6294       0.6754       0.0460       0.6837         0.6913       0.0077
# SVM (RBF)            0.6070       0.6415       0.0345       0.6709         0.6913       0.0204
#
# FINAL BEST MODEL AFTER TUNING: Logistic Regression
#    Tuned CV accuracy: 0.6786
#    Tuned test accuracy: 0.6964
#    Best parameters: {'C': 5.0, 'max_iter': 1000, 'penalty': 'l2', 'solver': 'liblinear'}

# %% [markdown]
# ## 6. MODEL SAVING

# %%
# Create models directory
import os
os.makedirs('../models', exist_ok=True)

# Save the best model and vectorizer
print("Saving best model and vectorizer...")

# Save the vectorizer (critical for preprocessing new inputs)
joblib.dump(vectorizer, '../models/tfidf_vectorizer.pkl')
print(f"   Vectorizer saved: ../models/tfidf_vectorizer.pkl")

# Save the best trained model
joblib.dump(best_model, f'../models/best_model_{best_model_name.lower().replace(" ", "_")}.pkl')
print(f"   Best model saved: ../models/best_model_{best_model_name.lower().replace(" ", "_")}.pkl")

# Save class mapping for interpretability
class_mapping.to_csv('../models/class_mapping.csv', index=False, encoding='utf-8')
print(f"   Class mapping saved: ../models/class_mapping.csv")

# Save model metadata
model_metadata = {
    'model_name': best_model_name,
    'model_type': type(best_model).__name__,
    'cv_accuracy': tuning_results[best_tuned_model_name]['best_cv_score'] if tuning_results else model_results[best_model_name]['cv_mean'],
    'test_accuracy': tuning_results[best_tuned_model_name]['test_accuracy'] if tuning_results else model_results[best_model_name]['test_accuracy'],
    'best_parameters': tuning_results[best_tuned_model_name]['best_params'] if tuning_results else 'default',
    'training_date': pd.Timestamp.now().strftime('%Y-%m-%d %H:%M:%S'),
    'training_samples': len(X_train_text),
    'test_samples': len(X_test_text),
    'num_classes': len(y_train.unique()),
    'vectorizer_params': {
        'max_features': vectorizer.max_features,
        'ngram_range': vectorizer.ngram_range,
        'min_df': vectorizer.min_df,
        'max_df': vectorizer.max_df
    }
}

# Save metadata as JSON
import json
with open('../models/model_metadata.json', 'w', encoding='utf-8') as f:
    json.dump(model_metadata, f, indent=2, ensure_ascii=False)
print(f"   Model metadata saved: ../models/model_metadata.json")

print(f"\nModel package ready for deployment!")
print(f"   Model: {best_model_name}")
print(f"   Accuracy: {model_metadata['test_accuracy']:.4f}")
print(f"   Files saved in: ../models/")
print(f"Saved in: ../models/")
print(f"Test accuracy: {model_metadata['test_accuracy']:.4f}")
print(f"Best model: {best_model_name}")
print(f"\nModel training and evaluation completed successfully!")
# Out:
# Saving best model and vectorizer...
#    Vectorizer saved: ../models/tfidf_vectorizer.pkl
#    Best model saved: ../models/best_model_logistic_regression.pkl
#    Class mapping saved: ../models/class_mapping.csv
#    Model metadata saved: ../models/model_metadata.json
#
# Model package ready for deployment!
#    Model: Logistic Regression
#    Accuracy: 0.6964
#    Files saved in: ../models/
# Saved in: ../models/
# Test accuracy: 0.6964
# Best model: Logistic Regression
#
# Model training and evaluation completed successfully!

# %% [markdown]
# ## 7. INTERACTIVE MODEL TESTING

# %%
def predict_question_department(question_text, show_probabilities=True):
    """
    Predict department for a new question
    
    Args:
        question_text (str): Bulgarian question text
        show_probabilities (bool): Whether to show prediction probabilities
    
    Returns:
        dict: Prediction results
    """
    # Preprocess the input (SAME AS TRAINING DATA)
    def clean_bulgarian_text(text):
        """Clean Bulgarian text for NLP processing - SAME AS PREPROCESSING"""
        import re
        import pandas as pd
        
        if pd.isna(text):
            return ""
        
        # Convert to string and lowercase
        text = str(text).lower()
        
        # Remove extra whitespace
        text = re.sub(r'\s+', ' ', text)
        
        # Remove leading/trailing whitespace
        text = text.strip()
        
        # Remove excessive punctuation (keep single punctuation)
        text = re.sub(r'[.]{2,}', '.', text)
        text = re.sub(r'[!]{2,}', '!', text)
        text = re.sub(r'[?]{2,}', '?', text)
        
        # Normalize quotes
        text = re.sub(r'[""„"]', '"', text)
        text = re.sub(r'[''`]', "'", text)
        
        return text
    
    # Apply SAME preprocessing as training (ONLY cleaning)
    processed_text = clean_bulgarian_text(question_text)
    
    # Vectorize using saved vectorizer
    text_vector = vectorizer.transform([processed_text])
    
    # Predict using best model
    prediction = best_model.predict(text_vector)[0]
    
    # Get probabilities if available
    if hasattr(best_model, 'predict_proba'):
        probabilities = best_model.predict_proba(text_vector)[0]
        class_names = best_model.classes_
        prob_dict = dict(zip(class_names, probabilities))
        
        # Sort by probability
        sorted_probs = sorted(prob_dict.items(), key=lambda x: x[1], reverse=True)
    else:
        sorted_probs = None
    
    # Create result
    result = {
        'original_text': question_text,
        'processed_text': processed_text,
        'predicted_department': prediction,
        'confidence': max(probabilities) if sorted_probs else None,
        'top_3_predictions': sorted_probs[:3] if sorted_probs else None
    }
    
    return result

# Test with some sample questions
print("Testing model with sample questions...")
print("\n" + "-"*50)

test_questions = [
   
   "Искам да кандидатствам за ипотечен кредит за жилище",
   "Колко е първоначалната вноска за жилищен кредит?",
   
   
   "Колко е лихвата за потребителски кредит?",
   "Искам потребителски кредит за кола",
   "Каква е максималната сума за потребителски кредит?",
   "Какви са изискванията за потребителски кредит?",
   
   
   "Искам бизнес сметка за моята фирма"
]

for i, question in enumerate(test_questions, 1):
    print(f"\n{i}. Testing: '{question}'")
    result = predict_question_department(question)
    
    print(f"   Predicted department: {result['predicted_department']}")
    if result['confidence']:
        print(f"   Confidence: {result['confidence']:.3f}")
    
    if result['top_3_predictions']:
        print(f"   Top 3 predictions:")
        for j, (dept, prob) in enumerate(result['top_3_predictions'], 1):
            print(f"      {j}. {dept}: {prob:.3f}")
    
    print(f"   Processed text: '{result['processed_text']}'")
# Out:
# Testing model with sample questions...
#
# --------------------------------------------------
#
# 1. Testing: 'Искам да кандидатствам за ипотечен кредит за жилище'
#    Predicted department: Пазар Жилищни и ипотечни кредити
#    Confidence: 0.832
#    Top 3 predictions:
#       1. Пазар Жилищни и ипотечни кредити: 0.832
#       2. ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ: 0.054
#       3. Пазар Потребителско кредитиране: 0.022
#    Processed text: 'искам да кандидатствам за ипотечен кредит за жилище'
#
# 2. Testing: 'Колко е първоначалната вноска за жилищен кредит?'
#    Predicted department: Пазар Жилищни и ипотечни кредити
#    Confidence: 0.802
#    Top 3 predictions:
#       1. Пазар Жилищни и ипотечни кредити: 0.802
#       2. ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ: 0.045
#       3. Пазар Потребителско кредитиране: 0.039
#    Processed text: 'колко е първоначалната вноска за жилищен кредит?'
#
# 3. Testing: 'Колко е лихвата за потребителски кредит?'
#    Predicted department: Пазар Потребителско кредитиране
#    Confidence: 0.807
#    Top 3 predictions:
#       1. Пазар Потребителско кредитиране: 0.807
#       2. Пазар Жилищни и ипотечни кредити: 0.053
#       3. Пазар Разсрочени плащания: 0.027
#    Processed text: 'колко е лихвата за потребителски кредит?'
#
# 4. Testing: 'Искам потребителски кредит за кола'
#    Predicted department: Пазар Потребителско кредитиране
#    Confidence: 0.815
#    Top 3 predictions:
#       1. Пазар Потребителско кредитиране: 0.815
#       2. Пазар Жилищни и ипотечни кредити: 0.079
#       3. Пазар Банково застраховане: 0.018
#    Processed text: 'искам потребителски кредит за кола'
#
# 5. Testing: 'Каква е максималната сума за потребителски кредит?'
#    Predicted department: Пазар Потребителско кредитиране
#    Confidence: 0.839
#    Top 3 predictions:
#       1. Пазар Потребителско кредитиране: 0.839
#       2. Support_Services: 0.023
#       3. Други: 0.021
#    Processed text: 'каква е максималната сума за потребителски кредит?'
#
# 6. Testing: 'Какви са изискванията за потребителски кредит?'
#    Predicted department: Пазар Потребителско кредитиране
#    Confidence: 0.814
#    Top 3 predictions:
#       1. Пазар Потребителско кредитиране: 0.814
#       2. Няколко пазара: 0.031
#       3. Пазар Жилищни и ипотечни кредити: 0.022
#    Processed text: 'какви са изискванията за потребителски кредит?'
#
# 7. Testing: 'Искам бизнес сметка за моята фирма'
#    Predicted department: Пазар Малък бизнес
#    Confidence: 0.711
#    Top 3 predictions:
#       1. Пазар Малък бизнес: 0.711
#       2. ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ: 0.104
#       3. Пазар Ежедневно банкиране: 0.064
#    Processed text: 'искам бизнес сметка за моята фирма'

# %% [markdown]
# ## 7. INTERACTIVE MODEL TESTING v2 with Model Data

# %%
import pandas as pd

# Load and prepare CSV
print("Preparing test data...")
df = pd.read_excel('../data/raw/Коментари за сортиране.xlsx', header=None, skiprows=1)
df.columns = ['index', 'message_uid', 'created_dttm', 'question', 'department', 'col5', 'col6', 'market_segment']
test_df = df[['question', 'department']].dropna().rename(columns={'department': 'expected_department'})
print(f"Loaded {len(test_df)} questions")

# Run predictions
print("\n" + "="*50)
print("CSV PREDICTION TEST")
print("="*50)

correct = 0
results = []

for idx, row in test_df.iterrows():
   question = row['question']
   expected = row['expected_department']
   
   result = predict_question_department(question)
   predicted = result['predicted_department']
   confidence = result['confidence']
   
   is_correct = predicted == expected
   if is_correct: correct += 1
   
   print(f"{idx+1:4d}. {'OK' if is_correct else 'NOT OK'} {confidence:.3f} | {predicted}")
   if not is_correct:
       print(f"       Expected: {expected}")
   
   results.append({'question': question, 'expected': expected, 'predicted': predicted, 'confidence': confidence, 'correct': is_correct})

# Summary
accuracy = correct / len(test_df)
avg_conf = sum(r['confidence'] for r in results) / len(results)

print(f"\nSUMMARY:")
print(f"Accuracy: {correct}/{len(test_df)} ({accuracy*100:.1f}%)")
print(f"Avg Confidence: {avg_conf:.3f}")

# Export results to Excel
print("\nEXPORTING RESULTS TO EXCEL...")

# Create results DataFrame
results_df = pd.DataFrame(results)

# Add status column for better readability
results_df['status'] = results_df['correct'].map({True: 'Correct', False: 'Wrong'})

# Reorder columns for better presentation
export_df = results_df[['question', 'expected', 'predicted', 'confidence', 'status', 'correct']]

# Create models directory if it doesn't exist
import os
os.makedirs('../models', exist_ok=True)

# Export to Excel with formatting
excel_path = '../models/model_test_results.xlsx'
with pd.ExcelWriter(excel_path, engine='openpyxl') as writer:
   # Main results
   export_df.to_excel(writer, sheet_name='Test Results', index=False)
   
   # Summary statistics
   summary_data = {
       'Metric': ['Total Questions', 'Correct Predictions', 'Wrong Predictions', 'Accuracy %', 'Average Confidence'],
       'Value': [len(test_df), correct, len(test_df)-correct, f"{accuracy*100:.1f}%", f"{avg_conf:.3f}"]
   }
   pd.DataFrame(summary_data).to_excel(writer, sheet_name='Summary', index=False)
   
   # Department accuracy breakdown
   dept_stats = []
   for dept in results_df['expected'].unique():
       dept_results = results_df[results_df['expected'] == dept]
       dept_correct = dept_results['correct'].sum()
       dept_total = len(dept_results)
       dept_acc = (dept_correct / dept_total * 100) if dept_total > 0 else 0
       dept_stats.append({
           'Department': dept,
           'Total': dept_total,
           'Correct': dept_correct,
           'Accuracy %': f"{dept_acc:.1f}%"
       })
   
   pd.DataFrame(dept_stats).sort_values('Accuracy %', ascending=False).to_excel(
       writer, sheet_name='Department Analysis', index=False)

print(f"Results exported to: {excel_path}")
print(f"   Sheet 1: Test Results ({len(export_df)} rows)")
print(f"   Sheet 2: Summary Statistics") 
print(f"   Sheet 3: Department Analysis")
# Out:
# Preparing test data...
# Loaded 1962 questions
#
# ==================================================
# CSV PREDICTION TEST
# ==================================================
#    1. OK 0.683 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
#    2. OK 0.533 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#    3. NOT OK 0.315 | Пазар Жилищни и ипотечни кредити
#        Expected: Пазар Ежедневно банкиране
#    4. OK 0.561 | Пазар Ежедневно банкиране
#    5. OK 0.735 | Пазар Ежедневно банкиране
#    6. OK 0.714 | Пазар Потребителско кредитиране
#    7. NOT OK 0.368 | Пазар Потребителско кредитиране
#        Expected: Пазар Ежедневно банкиране
#    8. OK 0.595 | Пазар Потребителско кредитиране
#    9. OK 0.739 | Пазар Малък бизнес
#   10. OK 0.597 | Други
#   11. OK 0.778 | Пазар Ежедневно банкиране
#   12. OK 0.576 | Няколко пазара
#   13. OK 0.600 | Пазар Ежедневно банкиране
#   14. OK 0.680 | Пазар Ежедневно банкиране
#   15. OK 0.628 | Пазар Жилищни и ипотечни кредити
#   16. OK 0.695 | Пазар Спестяване и инвестиции
#   17. OK 0.830 | Пазар Ежедневно банкиране
#   18. NOT OK 0.566 | Пазар Банково застраховане
#        Expected: Пазар Ежедневно банкиране
#   19. OK 0.576 | Други
#   20. OK 0.415 | Пазар Спестяване и инвестиции
#   21. OK 0.471 | Пазар Ежедневно банкиране
#   22. OK 0.721 | Пазар Жилищни и ипотечни кредити
#   23. OK 0.649 | Пазар Ежедневно банкиране
#   24. OK 0.460 | Пазар Потребителско кредитиране
#   25. NOT OK 0.579 | Пазар Спестяване и инвестиции
#        Expected: ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#   26. OK 0.740 | Пазар Жилищни и ипотечни кредити
#   27. OK 0.736 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#   28. OK 0.797 | Пазар Малък бизнес
#   29. OK 0.532 | Други
#   30. NOT OK 0.292 | Пазар Ежедневно банкиране
#        Expected: ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#   31. OK 0.428 | Други
#   32. OK 0.642 | Пазар Ежедневно банкиране
#   33. OK 0.670 | Няколко пазара
#   34. OK 0.534 | Пазар Потребителско кредитиране
#   35. OK 0.841 | Пазар Жилищни и ипотечни кредити
#   36. OK 0.756 | Пазар Потребителско кредитиране
#   37. NOT OK 0.321 | Няколко пазара
#        Expected: ДИРЕКЦИЯ КРЕДИТЕН РИСК ИНДИВИДУАЛНИ КЛИЕНТИ
#   38. OK 0.908 | Пазар Ежедневно банкиране
#   39. OK 0.775 | Пазар Жилищни и ипотечни кредити
#   40. OK 0.648 | Пазар Ежедневно банкиране
#   41. OK 0.609 | Пазар Ежедневно банкиране
#   42. OK 0.516 | Пазар Жилищни и ипотечни кредити
#   43. OK 0.769 | Пазар Ежедневно банкиране
#   44. OK 0.524 | Други
#   45. NOT OK 0.266 | Пазар Ежедневно банкиране
#        Expected: Други
#   46. OK 0.377 | Други
#   47. OK 0.530 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
#   48. OK 0.721 | Пазар Ежедневно банкиране
#   49. OK 0.766 | Пазар Жилищни и ипотечни кредити
#   50. OK 0.281 | Пазар Ежедневно банкиране
#   51. OK 0.452 | Пазар Ежедневно банкиране
#   52. OK 0.896 | Пазар Жилищни и ипотечни кредити
#   53. OK 0.521 | Няколко пазара
#   54. OK 0.777 | Пазар Ежедневно банкиране
#   55. OK 0.201 | Пазар Ежедневно банкиране
#   56. OK 0.435 | Пазар Ежедневно банкиране
#   57. OK 0.499 | Пазар Потребителско кредитиране
#   58. OK 0.570 | Други
#   59. NOT OK 0.426 | Support_Services
#        Expected: Пазар Ежедневно банкиране
#   60. NOT OK 0.320 | Пазар Спестяване и инвестиции
#        Expected: Други
#   61. OK 0.683 | Други
#   62. OK 0.725 | Пазар Разсрочени плащания
#   63. OK 0.278 | Други
#   64. OK 0.765 | Пазар Ежедневно банкиране
#   65. OK 0.782 | Пазар Потребителско кредитиране
#   66. OK 0.855 | Пазар Ежедневно банкиране
#   67. OK 0.292 | Пазар Ежедневно банкиране
#   68. NOT OK 0.371 | Други
#        Expected: Пазар Разсрочени плащания
#   69. OK 0.757 | Пазар Ежедневно банкиране
#   70. OK 0.720 | Пазар Ежедневно банкиране
#   71. OK 0.605 | Други
#   72. NOT OK 0.558 | Пазар Потребителско кредитиране
#        Expected: Пазар Ежедневно банкиране
#   73. OK 0.474 | Пазар Ежедневно банкиране
#   74. OK 0.695 | Пазар Ежедневно банкиране
#   75. OK 0.754 | Пазар Потребителско кредитиране
#   76. OK 0.691 | Пазар Ежедневно банкиране
#   77. OK 0.433 | Пазар Жилищни и ипотечни кредити
#   78. NOT OK 0.757 | Пазар Ежедневно банкиране
#        Expected: Пазар Малък бизнес
#   79. OK 0.680 | Пазар Спестяване и инвестиции
#   80. OK 0.720 | Пазар Разсрочени плащания
#   81. OK 0.677 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#   82. OK 0.614 | Пазар Потребителско кредитиране
#   83. OK 0.549 | Пазар Ежедневно банкиране
#   84. OK 0.571 | Пазар Спестяване и инвестиции
#   85. OK 0.764 | Пазар Малък бизнес
#   86. NOT OK 0.633 | Support_Services
#        Expected: ПРАВНО
#   87. NOT OK 0.317 | Пазар Спестяване и инвестиции
#        Expected: Пазар Ежедневно банкиране
#   88. OK 0.758 | Пазар Потребителско кредитиране
#   89. OK 0.704 | Други
#   90. OK 0.584 | Други
#   91. OK 0.592 | Други
#   92. NOT OK 0.223 | Пазар Спестяване и инвестиции
#        Expected: Пазар Жилищни и ипотечни кредити
#   93. OK 0.359 | Пазар Ежедневно банкиране
#   94. OK 0.732 | Пазар Ежедневно банкиране
#   95. OK 0.657 | Пазар Разсрочени плащания
#   96. OK 0.818 | Пазар Жилищни и ипотечни кредити
#   97. OK 0.429 | Пазар Ежедневно банкиране
#   98. OK 0.754 | Пазар Разсрочени плащания
#   99. OK 0.675 | Пазар Спестяване и инвестиции
#  100. OK 0.798 | Пазар Потребителско кредитиране
#  101. NOT OK 0.362 | Други
#        Expected: ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  102. OK 0.616 | Пазар Жилищни и ипотечни кредити
#  103. OK 0.731 | Пазар Ежедневно банкиране
#  104. OK 0.529 | Пазар Ежедневно банкиране
#  105. OK 0.703 | Пазар Ежедневно банкиране
#  106. OK 0.297 | Пазар Спестяване и инвестиции
#  107. OK 0.611 | Пазар Спестяване и инвестиции
#  108. OK 0.519 | Пазар Спестяване и инвестиции
#  109. OK 0.782 | Пазар Малък бизнес
#  110. OK 0.585 | Няколко пазара
#  111. OK 0.554 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
#  112. NOT OK 0.640 | Support_Services
#        Expected: ПРАВНО
#  113. OK 0.629 | Пазар Разсрочени плащания
#  114. OK 0.305 | Пазар Ежедневно банкиране
#  115. OK 0.648 | Пазар Ежедневно банкиране
#  116. OK 0.657 | Пазар Жилищни и ипотечни кредити
#  117. OK 0.765 | Пазар Ежедневно банкиране
#  118. OK 0.251 | Пазар Ежедневно банкиране
#  119. OK 0.401 | Пазар Ежедневно банкиране
#  120. OK 0.447 | Пазар Ежедневно банкиране
#  121. OK 0.816 | Пазар Жилищни и ипотечни кредити
#  122. OK 0.835 | Пазар Спестяване и инвестиции
#  123. OK 0.712 | Пазар Разсрочени плащания
#  124. OK 0.764 | Пазар Ежедневно банкиране
#  125. OK 0.622 | Пазар Потребителско кредитиране
#  126. OK 0.445 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  127. OK 0.575 | Пазар Спестяване и инвестиции
#  128. OK 0.764 | Пазар Ежедневно банкиране
#  129. OK 0.538 | Пазар Ежедневно банкиране
#  130. OK 0.343 | Други
#  131. OK 0.558 | Други
#  132. OK 0.616 | Пазар Спестяване и инвестиции
#  133. OK 0.689 | Пазар Банково застраховане
#  134. OK 0.295 | Пазар Ежедневно банкиране
#  135. OK 0.371 | Други
#  136. OK 0.720 | Пазар Потребителско кредитиране
#  137. NOT OK 0.461 | Други
#        Expected: Пазар Ежедневно банкиране
#  138. OK 0.799 | Пазар Разсрочени плащания
#  139. OK 0.631 | Пазар Ежедневно банкиране
#  140. OK 0.269 | Пазар Ежедневно банкиране
#  141. OK 0.491 | Пазар Жилищни и ипотечни кредити
#  142. OK 0.766 | Пазар Разсрочени плащания
#  143. OK 0.499 | Пазар Ежедневно банкиране
#  144. OK 0.574 | Няколко пазара
#  145. OK 0.646 | Пазар Ежедневно банкиране
#  146. NOT OK 0.328 | Други
#        Expected: Пазар Ежедневно банкиране
#  147. NOT OK 0.350 | Други
#        Expected: Пазар Ежедневно банкиране
#  148. OK 0.693 | Други
#  149. OK 0.299 | Други
#  150. OK 0.533 | Няколко пазара
#  151. OK 0.697 | Пазар Ежедневно банкиране
#  152. OK 0.844 | Пазар Банково застраховане
#  153. NOT OK 0.716 | Support_Services
#        Expected: CRM
#  154. OK 0.551 | Други
#  155. OK 0.607 | ДИРЕКЦИЯ КРЕДИТЕН РИСК ИНДИВИДУАЛНИ КЛИЕНТИ
#  156. NOT OK 0.446 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
#        Expected: ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  157. OK 0.588 | Пазар Жилищни и ипотечни кредити
#  158. OK 0.691 | Пазар Ежедневно банкиране
#  159. OK 0.656 | Пазар Разсрочени плащания
#  160. OK 0.377 | Пазар Жилищни и ипотечни кредити
#  161. OK 0.477 | Пазар Ежедневно банкиране
#  162. OK 0.595 | Пазар Ежедневно банкиране
#  163. OK 0.673 | Други
#  164. OK 0.740 | Пазар Жилищни и ипотечни кредити
#  165. OK 0.636 | Пазар Ежедневно банкиране
#  166. OK 0.669 | Пазар Ежедневно банкиране
#  167. OK 0.685 | Пазар Ежедневно банкиране
#  168. OK 0.537 | Пазар Жилищни и ипотечни кредити
#  169. NOT OK 0.200 | Пазар Жилищни и ипотечни кредити
#        Expected: Пазар Ежедневно банкиране
#  170. OK 0.771 | Пазар Банково застраховане
#  171. OK 0.565 | Няколко пазара
#  172. OK 0.717 | Пазар Спестяване и инвестиции
#  173. OK 0.684 | Пазар Малък бизнес
#  174. OK 0.572 | Пазар Малък бизнес
#  175. NOT OK 0.250 | Други
#        Expected: ДИРЕКЦИЯ КРЕДИТЕН РИСК ИНДИВИДУАЛНИ КЛИЕНТИ
#  176. OK 0.209 | Пазар Ежедневно банкиране
#  177. OK 0.618 | Пазар Жилищни и ипотечни кредити
#  178. OK 0.707 | Други
#  179. OK 0.514 | Пазар Спестяване и инвестиции
#  180. OK 0.550 | Пазар Ежедневно банкиране
#  181. OK 0.620 | Няколко пазара
#  182. OK 0.583 | Други
#  183. OK 0.664 | Пазар Ежедневно банкиране
#  184. OK 0.716 | Пазар Потребителско кредитиране
#  185. OK 0.672 | Други
#  186. OK 0.636 | Пазар Ежедневно банкиране
#  187. OK 0.475 | Други
#  188. OK 0.817 | Пазар Жилищни и ипотечни кредити
#  189. OK 0.452 | Пазар Жилищни и ипотечни кредити
#  190. OK 0.702 | Пазар Ежедневно банкиране
#  191. OK 0.754 | Пазар Разсрочени плащания
#  192. OK 0.804 | Пазар Разсрочени плащания
#  193. OK 0.404 | Пазар Жилищни и ипотечни кредити
#  194. OK 0.650 | Пазар Ежедневно банкиране
#  195. OK 0.410 | Други
#  196. OK 0.617 | Пазар Ежедневно банкиране
#  197. OK 0.165 | Пазар Ежедневно банкиране
#  198. OK 0.613 | Пазар Потребителско кредитиране
#  199. OK 0.703 | ДИРЕКЦИЯ КРЕДИТЕН РИСК ИНДИВИДУАЛНИ КЛИЕНТИ
#  200. OK 0.456 | Пазар Малък бизнес
#  201. OK 0.269 | ДИРЕКЦИЯ КРЕДИТЕН РИСК ИНДИВИДУАЛНИ КЛИЕНТИ
#  202. OK 0.754 | Други
#  203. OK 0.521 | Пазар Потребителско кредитиране
#  204. OK 0.721 | Пазар Жилищни и ипотечни кредити
#  205. OK 0.715 | ДИРЕКЦИЯ КРЕДИТЕН РИСК ИНДИВИДУАЛНИ КЛИЕНТИ
#  206. OK 0.635 | Пазар Разсрочени плащания
#  207. NOT OK 0.595 | Support_Services
#        Expected: ПРАВНО
#  208. OK 0.633 | Други
#  209. OK 0.887 | Пазар Ежедневно банкиране
#  210. OK 0.752 | Пазар Малък бизнес
#  211. NOT OK 0.345 | Пазар Ежедневно банкиране
#        Expected: ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  212. NOT OK 0.406 | Пазар Жилищни и ипотечни кредити
#        Expected: Пазар Малък бизнес
#  213. OK 0.692 | Пазар Ежедневно банкиране
#  214. OK 0.740 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
#  215. OK 0.545 | Пазар Ежедневно банкиране
#  216. OK 0.833 | Пазар Банково застраховане
#  217. OK 0.802 | Пазар Потребителско кредитиране
#  218. NOT OK 0.366 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#        Expected: Пазар Ежедневно банкиране
#  219. OK 0.732 | Пазар Малък бизнес
#  220. OK 0.717 | Пазар Банково застраховане
#  221. OK 0.516 | Други
#  222. OK 0.794 | Пазар Банково застраховане
#  223. OK 0.708 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  224. OK 0.655 | Пазар Ежедневно банкиране
#  225. OK 0.791 | Пазар Малък бизнес
#  226. OK 0.411 | Други
#  227. OK 0.787 | Пазар Жилищни и ипотечни кредити
#  228. OK 0.443 | Други
#  229. OK 0.770 | Пазар Ежедневно банкиране
#  230. OK 0.769 | Пазар Малък бизнес
#  231. OK 0.624 | Други
#  232. OK 0.561 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  233. OK 0.404 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  234. OK 0.814 | Пазар Разсрочени плащания
#  235. OK 0.427 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  236. OK 0.566 | Пазар Жилищни и ипотечни кредити
#  237. OK 0.494 | Пазар Жилищни и ипотечни кредити
#  238. OK 0.376 | Пазар Ежедневно банкиране
#  239. OK 0.771 | Пазар Жилищни и ипотечни кредити
#  240. OK 0.554 | Пазар Малък бизнес
#  241. OK 0.747 | Пазар Ежедневно банкиране
#  242. OK 0.799 | Пазар Потребителско кредитиране
#  243. OK 0.709 | Пазар Разсрочени плащания
#  244. OK 0.530 | Пазар Жилищни и ипотечни кредити
#  245. NOT OK 0.674 | Support_Services
#        Expected: ПРАВНО
#  246. OK 0.739 | Пазар Ежедневно банкиране
#  247. OK 0.648 | Няколко пазара
#  248. OK 0.367 | Пазар Ежедневно банкиране
#  249. OK 0.504 | Пазар Ежедневно банкиране
#  250. OK 0.527 | Пазар Малък бизнес
#  251. NOT OK 0.503 | Пазар Разсрочени плащания
#        Expected: Пазар Ежедневно банкиране
#  252. OK 0.735 | Пазар Жилищни и ипотечни кредити
#  253. OK 0.707 | Пазар Разсрочени плащания
#  254. OK 0.620 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
#  255. OK 0.703 | Пазар Ежедневно банкиране
#  256. NOT OK 0.381 | Пазар Ежедневно банкиране
#        Expected: Пазар Малък бизнес
#  257. OK 0.519 | Няколко пазара
#  258. OK 0.481 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  259. OK 0.421 | Други
#  260. OK 0.661 | Пазар Ежедневно банкиране
#  261. OK 0.468 | Пазар Ежедневно банкиране
#  262. OK 0.671 | ДИРЕКЦИЯ КРЕДИТЕН РИСК ИНДИВИДУАЛНИ КЛИЕНТИ
#  263. OK 0.746 | Пазар Ежедневно банкиране
#  264. NOT OK 0.326 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#        Expected: Пазар Ежедневно банкиране
#  265. OK 0.624 | Няколко пазара
#  266. OK 0.632 | ДИРЕКЦИЯ КРЕДИТЕН РИСК ИНДИВИДУАЛНИ КЛИЕНТИ
#  267. OK 0.771 | Пазар Банково застраховане
#  268. OK 0.696 | Пазар Ежедневно банкиране
#  269. OK 0.755 | Пазар Малък бизнес
#  270. OK 0.548 | Пазар Банково застраховане
#  271. OK 0.676 | Пазар Жилищни и ипотечни кредити
#  272. OK 0.744 | Пазар Ежедневно банкиране
#  273. OK 0.832 | Пазар Ежедневно банкиране
#  274. NOT OK 0.587 | Support_Services
#        Expected: ПРАВНО
#  275. OK 0.276 | Пазар Ежедневно банкиране
#  276. OK 0.516 | Пазар Ежедневно банкиране
#  277. OK 0.512 | Пазар Ежедневно банкиране
#  278. NOT OK 0.332 | Няколко пазара
#        Expected: Пазар Жилищни и ипотечни кредити
#  279. OK 0.672 | Други
#  280. OK 0.628 | Пазар Спестяване и инвестиции
#  281. OK 0.623 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  282. OK 0.608 | Пазар Жилищни и ипотечни кредити
#  283. NOT OK 0.458 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#        Expected: Няколко пазара
#  284. OK 0.601 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  285. OK 0.588 | Пазар Разсрочени плащания
#  286. OK 0.505 | Други
#  287. OK 0.780 | Други
#  288. OK 0.524 | Други
#  289. OK 0.833 | Пазар Ежедневно банкиране
#  290. OK 0.697 | Пазар Ежедневно банкиране
#  291. OK 0.613 | Пазар Жилищни и ипотечни кредити
#  292. NOT OK 0.207 | Други
#        Expected: Пазар Ежедневно банкиране
#  293. OK 0.534 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
#  294. OK 0.594 | Пазар Ежедневно банкиране
#  295. OK 0.295 | Други
#  296. OK 0.529 | Пазар Ежедневно банкиране
#  297. OK 0.661 | Пазар Жилищни и ипотечни кредити
#  298. OK 0.559 | Други
#  299. OK 0.791 | Пазар Ежедневно банкиране
#  300. OK 0.702 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  301. OK 0.659 | Пазар Спестяване и инвестиции
#  302. OK 0.595 | Пазар Спестяване и инвестиции
#  303. OK 0.766 | Пазар Жилищни и ипотечни кредити
#  304. OK 0.692 | Пазар Ежедневно банкиране
#  305. OK 0.693 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
#  306. OK 0.493 | Пазар Потребителско кредитиране
#  307. OK 0.536 | Пазар Ежедневно банкиране
#  308. OK 0.601 | Пазар Разсрочени плащания
#  309. OK 0.728 | Пазар Банково застраховане
#  310. OK 0.832 | Пазар Жилищни и ипотечни кредити
#  311. OK 0.795 | Пазар Малък бизнес
#  312. OK 0.683 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  313. OK 0.665 | Пазар Жилищни и ипотечни кредити
#  314. OK 0.669 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
#  315. OK 0.350 | Други
#  316. OK 0.741 | Пазар Ежедневно банкиране
#  317. OK 0.746 | Пазар Жилищни и ипотечни кредити
#  318. OK 0.395 | Пазар Ежедневно банкиране
#  319. OK 0.611 | Други
#  320. OK 0.350 | Други
#  321. OK 0.465 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  322. OK 0.419 | Пазар Ежедневно банкиране
#  323. OK 0.535 | Други
#  324. NOT OK 0.375 | Други
#        Expected: Няколко пазара
#  325. OK 0.621 | Пазар Разсрочени плащания
#  326. OK 0.774 | Пазар Ежедневно банкиране
#  327. OK 0.425 | Пазар Жилищни и ипотечни кредити
#  328. OK 0.394 | Пазар Ежедневно банкиране
#  329. OK 0.386 | Други
#  330. OK 0.596 | Пазар Спестяване и инвестиции
#  331. OK 0.578 | Пазар Жилищни и ипотечни кредити
#  332. OK 0.585 | Пазар Ежедневно банкиране
#  333. OK 0.517 | Пазар Потребителско кредитиране
#  334. OK 0.800 | Пазар Жилищни и ипотечни кредити
#  335. OK 0.350 | Други
#  336. OK 0.541 | Други
#  337. OK 0.860 | Пазар Жилищни и ипотечни кредити
#  338. OK 0.771 | Пазар Малък бизнес
#  339. OK 0.539 | Пазар Разсрочени плащания
#  340. OK 0.666 | Пазар Жилищни и ипотечни кредити
#  341. OK 0.579 | Пазар Жилищни и ипотечни кредити
#  342. OK 0.664 | Пазар Жилищни и ипотечни кредити
#  343. OK 0.629 | Няколко пазара
#  344. OK 0.566 | Пазар Малък бизнес
#  345. OK 0.727 | Пазар Спестяване и инвестиции
#  346. OK 0.548 | Пазар Банково застраховане
#  347. OK 0.671 | Пазар Ежедневно банкиране
#  348. OK 0.547 | Други
#  349. OK 0.579 | Пазар Потребителско кредитиране
#  350. OK 0.403 | Пазар Жилищни и ипотечни кредити
#  351. OK 0.594 | Пазар Ежедневно банкиране
#  352. OK 0.731 | Пазар Жилищни и ипотечни кредити
#  353. OK 0.524 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  354. OK 0.624 | Пазар Ежедневно банкиране
#  355. OK 0.635 | Пазар Малък бизнес
#  356. OK 0.572 | Други
#  357. OK 0.875 | Пазар Ежедневно банкиране
#  358. OK 0.627 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
#  359. OK 0.511 | Пазар Потребителско кредитиране
#  360. OK 0.641 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  361. OK 0.529 | Други
#  362. OK 0.590 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
#  363. OK 0.432 | Пазар Разсрочени плащания
#  364. OK 0.587 | Пазар Ежедневно банкиране
#  365. OK 0.499 | Пазар Ежедневно банкиране
#  366. OK 0.781 | Пазар Потребителско кредитиране
#  367. OK 0.350 | Пазар Ежедневно банкиране
#  368. OK 0.712 | Пазар Потребителско кредитиране
#  369. OK 0.591 | Други
#  370. OK 0.373 | Пазар Ежедневно банкиране
#  371. OK 0.357 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
#  372. OK 0.428 | Пазар Ежедневно банкиране
#  373. OK 0.631 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
#  374. NOT OK 0.350 | Други
#        Expected: Пазар Малък бизнес
#  375. OK 0.743 | Пазар Ежедневно банкиране
#  376. OK 0.520 | Други
#  377. OK 0.578 | Пазар Жилищни и ипотечни кредити
#  378. OK 0.729 | Пазар Малък бизнес
#  379. OK 0.371 | Други
#  380. OK 0.622 | Други
#  381. OK 0.578 | Други
#  382. OK 0.645 | Пазар Ежедневно банкиране
#  383. OK 0.604 | Пазар Малък бизнес
#  384. OK 0.795 | Пазар Разсрочени плащания
#  385. NOT OK 0.422 | Други
#        Expected: Пазар Жилищни и ипотечни кредити
#  386. OK 0.747 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
#  387. OK 0.645 | Други
#  388. OK 0.717 | Пазар Потребителско кредитиране
#  389. OK 0.672 | Други
#  390. NOT OK 0.415 | Пазар Банково застраховане
#        Expected: Други
#  391. OK 0.607 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  392. OK 0.682 | Пазар Разсрочени плащания
#  393. OK 0.672 | Пазар Потребителско кредитиране
#  394. OK 0.486 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  395. NOT OK 0.631 | Support_Services
#        Expected: CRM
#  396. OK 0.864 | Пазар Ежедневно банкиране
#  397. OK 0.559 | Пазар Ежедневно банкиране
#  398. OK 0.606 | Пазар Разсрочени плащания
#  399. OK 0.772 | Пазар Ежедневно банкиране
#  400. NOT OK 0.418 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
#        Expected: Пазар Ежедневно банкиране
#  401. OK 0.616 | ДИРЕКЦИЯ КРЕДИТЕН РИСК ИНДИВИДУАЛНИ КЛИЕНТИ
#  402. OK 0.554 | Пазар Ежедневно банкиране
#  403. NOT OK 0.299 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
#        Expected: Пазар Ежедневно банкиране
#  404. OK 0.714 | Пазар Потребителско кредитиране
#  405. NOT OK 0.165 | Пазар Ежедневно банкиране
#        Expected: Пазар Потребителско кредитиране
#  406. OK 0.594 | Други
#  407. OK 0.767 | Пазар Банково застраховане
#  408. NOT OK 0.347 | Support_Services
#        Expected: Пазар Ежедневно банкиране
#  409. OK 0.753 | Пазар Банково застраховане
#  410. OK 0.585 | Пазар Разсрочени плащания
#  411. NOT OK 0.350 | Други
#        Expected: Пазар Жилищни и ипотечни кредити
#  412. OK 0.508 | Пазар Ежедневно банкиране
#  413. OK 0.350 | Други
#  414. OK 0.635 | ДИРЕКЦИЯ КРЕДИТЕН РИСК ИНДИВИДУАЛНИ КЛИЕНТИ
#  415. NOT OK 0.321 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
#        Expected: Пазар Ежедневно банкиране
#  416. OK 0.626 | Пазар Разсрочени плащания
#  417. OK 0.781 | Пазар Разсрочени плащания
#  418. OK 0.588 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  419. OK 0.586 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  420. OK 0.896 | Пазар Жилищни и ипотечни кредити
#  421. OK 0.773 | Пазар Жилищни и ипотечни кредити
#  422. OK 0.655 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  423. OK 0.463 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  424. OK 0.666 | Пазар Жилищни и ипотечни кредити
#  425. NOT OK 0.236 | ДИРЕКЦИЯ КРЕДИТЕН РИСК ИНДИВИДУАЛНИ КЛИЕНТИ
#        Expected: Пазар Малък бизнес
#  426. OK 0.584 | Други
#  427. OK 0.575 | Пазар Ежедневно банкиране
#  428. OK 0.740 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
#  429. NOT OK 0.258 | ДИРЕКЦИЯ КРЕДИТЕН РИСК ИНДИВИДУАЛНИ КЛИЕНТИ
#        Expected: Пазар Потребителско кредитиране
#  430. OK 0.559 | Пазар Потребителско кредитиране
#  431. OK 0.756 | Пазар Ежедневно банкиране
#  432. OK 0.526 | Пазар Ежедневно банкиране
#  433. OK 0.702 | Пазар Ежедневно банкиране
#  434. OK 0.784 | Пазар Ежедневно банкиране
#  435. OK 0.603 | Пазар Разсрочени плащания
#  436. OK 0.804 | Пазар Ежедневно банкиране
#  437. OK 0.782 | Пазар Ежедневно банкиране
#  438. NOT OK 0.295 | Други
#        Expected: CRM
#  439. OK 0.551 | Пазар Ежедневно банкиране
#  440. OK 0.568 | Пазар Ежедневно банкиране
#  441. OK 0.602 | Пазар Жилищни и ипотечни кредити
#  442. OK 0.635 | ДИРЕКЦИЯ КРЕДИТЕН РИСК ИНДИВИДУАЛНИ КЛИЕНТИ
#  443. OK 0.728 | Пазар Ежедневно банкиране
#  444. OK 0.691 | Други
#  445. OK 0.339 | Пазар Жилищни и ипотечни кредити
#  446. OK 0.685 | Пазар Банково застраховане
#  447. OK 0.425 | Други
#  448. OK 0.683 | Пазар Жилищни и ипотечни кредити
#  449. OK 0.697 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
#  450. OK 0.865 | Пазар Жилищни и ипотечни кредити
#  451. OK 0.757 | Пазар Ежедневно банкиране
#  452. OK 0.642 | Пазар Жилищни и ипотечни кредити
#  453. OK 0.649 | Пазар Разсрочени плащания
#  454. OK 0.693 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  455. OK 0.407 | Пазар Потребителско кредитиране
#  456. OK 0.696 | Пазар Банково застраховане
#  457. NOT OK 0.297 | Няколко пазара
#        Expected: Други
#  458. OK 0.559 | Други
#  459. OK 0.574 | Няколко пазара
#  460. OK 0.785 | Пазар Потребителско кредитиране
#  461. OK 0.228 | Пазар Ежедневно банкиране
#  462. OK 0.387 | Пазар Ежедневно банкиране
#  463. OK 0.356 | Пазар Ежедневно банкиране
#  464. OK 0.714 | Пазар Ежедневно банкиране
#  465. OK 0.770 | Пазар Спестяване и инвестиции
#  466. OK 0.498 | Пазар Ежедневно банкиране
#  467. OK 0.406 | Пазар Жилищни и ипотечни кредити
#  468. OK 0.809 | Пазар Потребителско кредитиране
#  469. OK 0.536 | Пазар Жилищни и ипотечни кредити
#  470. OK 0.787 | Пазар Потребителско кредитиране
#  471. OK 0.494 | Други
#  472. OK 0.782 | Пазар Банково застраховане
#  473. OK 0.752 | Пазар Разсрочени плащания
#  474. NOT OK 0.248 | Други
#        Expected: Пазар Ежедневно банкиране
#  475. OK 0.641 | Пазар Спестяване и инвестиции
#  476. OK 0.638 | Няколко пазара
#  477. OK 0.686 | Пазар Жилищни и ипотечни кредити
#  478. OK 0.785 | Пазар Потребителско кредитиране
#  479. OK 0.787 | Пазар Ежедневно банкиране
#  480. OK 0.754 | Пазар Малък бизнес
#  481. OK 0.799 | Пазар Жилищни и ипотечни кредити
#  482. OK 0.433 | Пазар Ежедневно банкиране
#  483. OK 0.613 | Пазар Ежедневно банкиране
#  484. OK 0.752 | Пазар Разсрочени плащания
#  485. OK 0.614 | Пазар Потребителско кредитиране
#  486. OK 0.533 | Пазар Разсрочени плащания
#  487. OK 0.515 | Други
#  488. OK 0.350 | Други
#  489. OK 0.699 | Пазар Ежедневно банкиране
#  490. OK 0.743 | Пазар Потребителско кредитиране
#  491. OK 0.649 | ДИРЕКЦИЯ КРЕДИТЕН РИСК ИНДИВИДУАЛНИ КЛИЕНТИ
#  492. OK 0.726 | Пазар Разсрочени плащания
#  493. OK 0.697 | Пазар Малък бизнес
#  494. OK 0.769 | Пазар Ежедневно банкиране
#  495. OK 0.269 | Други
#  496. NOT OK 0.586 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#        Expected: Пазар Ежедневно банкиране
#  497. OK 0.472 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  498. OK 0.525 | Пазар Жилищни и ипотечни кредити
#  499. OK 0.633 | Няколко пазара
#  500. OK 0.732 | Други
#  501. NOT OK 0.314 | Пазар Ежедневно банкиране
#        Expected: Пазар Потребителско кредитиране
#  502. OK 0.322 | Други
#  503. OK 0.579 | Пазар Ежедневно банкиране
#  504. NOT OK 0.209 | Пазар Ежедневно банкиране
#        Expected: Други
#  505. OK 0.572 | Пазар Ежедневно банкиране
#  506. OK 0.355 | Пазар Ежедневно банкиране
#  507. OK 0.520 | Пазар Жилищни и ипотечни кредити
#  508. OK 0.373 | Пазар Разсрочени плащания
#  509. OK 0.478 | Пазар Ежедневно банкиране
#  510. OK 0.517 | Пазар Банково застраховане
#  511. OK 0.638 | Други
#  512. OK 0.275 | Други
#  513. OK 0.597 | Пазар Малък бизнес
#  514. OK 0.602 | Пазар Жилищни и ипотечни кредити
#  515. OK 0.751 | Пазар Ежедневно банкиране
#  516. NOT OK 0.226 | Други
#        Expected: Пазар Жилищни и ипотечни кредити
#  517. OK 0.820 | Пазар Ежедневно банкиране
#  518. OK 0.589 | Пазар Ежедневно банкиране
#  519. OK 0.760 | Пазар Жилищни и ипотечни кредити
#  520. OK 0.745 | Пазар Потребителско кредитиране
#  521. OK 0.820 | Пазар Жилищни и ипотечни кредити
#  522. NOT OK 0.609 | Пазар Ежедневно банкиране
#        Expected: Други
#  523. OK 0.855 | Пазар Ежедневно банкиране
#  524. OK 0.561 | Пазар Малък бизнес
#  525. OK 0.479 | Пазар Ежедневно банкиране
#  526. OK 0.584 | Пазар Малък бизнес
#  527. OK 0.537 | Пазар Разсрочени плащания
#  528. OK 0.460 | Пазар Ежедневно банкиране
#  529. OK 0.666 | Пазар Ежедневно банкиране
#  530. OK 0.250 | Пазар Ежедневно банкиране
#  531. OK 0.604 | Пазар Ежедневно банкиране
#  532. OK 0.857 | Пазар Ежедневно банкиране
#  533. OK 0.701 | Пазар Малък бизнес
#  534. OK 0.467 | Пазар Ежедневно банкиране
#  535. OK 0.550 | ДИРЕКЦИЯ КРЕДИТЕН РИСК ИНДИВИДУАЛНИ КЛИЕНТИ
#  536. OK 0.532 | Пазар Ежедневно банкиране
#  537. OK 0.794 | Пазар Жилищни и ипотечни кредити
#  538. OK 0.688 | Пазар Ежедневно банкиране
#  539. OK 0.596 | Пазар Потребителско кредитиране
#  540. OK 0.664 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  541. OK 0.505 | Няколко пазара
#  542. OK 0.703 | Пазар Жилищни и ипотечни кредити
#  543. OK 0.388 | Пазар Жилищни и ипотечни кредити
#  544. OK 0.757 | Пазар Ежедневно банкиране
#  545. OK 0.674 | Други
#  546. OK 0.735 | Пазар Ежедневно банкиране
#  547. OK 0.700 | Пазар Банково застраховане
#  548. OK 0.554 | Пазар Ежедневно банкиране
#  549. OK 0.833 | Пазар Ежедневно банкиране
#  550. NOT OK 0.513 | Support_Services
#        Expected: Пазар Разсрочени плащания
#  551. OK 0.815 | Пазар Разсрочени плащания
#  552. NOT OK 0.305 | ДИРЕКЦИЯ КРЕДИТЕН РИСК ИНДИВИДУАЛНИ КЛИЕНТИ
#        Expected: Пазар Ежедневно банкиране
#  553. OK 0.610 | Пазар Ежедневно банкиране
#  554. OK 0.767 | Пазар Разсрочени плащания
#  555. OK 0.707 | Пазар Потребителско кредитиране
#  556. OK 0.417 | Други
#  557. OK 0.829 | Пазар Ежедневно банкиране
#  558. NOT OK 0.686 | Support_Services
#        Expected: ПРАВНО
#  559. NOT OK 0.387 | Други
#        Expected: Пазар Ежедневно банкиране
#  560. OK 0.735 | Пазар Ежедневно банкиране
#  561. OK 0.688 | Пазар Жилищни и ипотечни кредити
#  562. OK 0.573 | Пазар Жилищни и ипотечни кредити
#  563. OK 0.707 | Пазар Банково застраховане
#  564. OK 0.447 | Други
#  565. OK 0.762 | Пазар Малък бизнес
#  566. OK 0.657 | Пазар Потребителско кредитиране
#  567. NOT OK 0.277 | Пазар Малък бизнес
#        Expected: Други
#  568. OK 0.340 | Пазар Жилищни и ипотечни кредити
#  569. OK 0.785 | Пазар Ежедневно банкиране
#  570. NOT OK 0.621 | Support_Services
#        Expected: ПРАВНО
#  571. OK 0.694 | Пазар Жилищни и ипотечни кредити
#  572. OK 0.282 | Пазар Жилищни и ипотечни кредити
#  573. OK 0.679 | ДИРЕКЦИЯ КРЕДИТЕН РИСК ИНДИВИДУАЛНИ КЛИЕНТИ
#  574. OK 0.597 | Пазар Банково застраховане
#  575. OK 0.682 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  576. OK 0.801 | Пазар Потребителско кредитиране
#  577. OK 0.755 | Пазар Жилищни и ипотечни кредити
#  578. OK 0.782 | Пазар Разсрочени плащания
#  579. OK 0.609 | Пазар Ежедневно банкиране
#  580. OK 0.629 | Пазар Ежедневно банкиране
#  581. NOT OK 0.641 | Пазар Ежедневно банкиране
#        Expected: CRM
#  582. OK 0.686 | Пазар Ежедневно банкиране
#  583. OK 0.670 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
#  584. OK 0.587 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  585. OK 0.517 | Други
#  586. OK 0.642 | Други
#  587. OK 0.556 | Пазар Банково застраховане
#  588. OK 0.655 | Пазар Ежедневно банкиране
#  589. OK 0.657 | Пазар Банково застраховане
#  590. OK 0.754 | Пазар Ежедневно банкиране
#  591. OK 0.735 | Пазар Ежедневно банкиране
#  592. OK 0.789 | Пазар Разсрочени плащания
#  593. OK 0.781 | Пазар Банково застраховане
#  594. OK 0.536 | Пазар Спестяване и инвестиции
#  595. OK 0.706 | Пазар Жилищни и ипотечни кредити
#  596. OK 0.684 | Пазар Ежедневно банкиране
#  597. NOT OK 0.222 | Пазар Потребителско кредитиране
#        Expected: Пазар Жилищни и ипотечни кредити
#  598. OK 0.638 | Пазар Ежедневно банкиране
#  599. OK 0.780 | Други
#  600. OK 0.330 | Пазар Ежедневно банкиране
#  601. OK 0.672 | Пазар Потребителско кредитиране
#  602. OK 0.690 | Пазар Спестяване и инвестиции
#  603. NOT OK 0.467 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
#        Expected: Пазар Ежедневно банкиране
#  604. OK 0.630 | Пазар Разсрочени плащания
#  605. OK 0.743 | Други
#  606. OK 0.558 | Пазар Потребителско кредитиране
#  607. OK 0.702 | Пазар Спестяване и инвестиции
#  608. OK 0.521 | Пазар Банково застраховане
#  609. OK 0.725 | Пазар Разсрочени плащания
#  610. OK 0.393 | Други
#  611. OK 0.812 | Пазар Ежедневно банкиране
#  612. NOT OK 0.371 | Други
#        Expected: Пазар Разсрочени плащания
#  613. OK 0.608 | Пазар Ежедневно банкиране
#  614. NOT OK 0.523 | Support_Services
#        Expected: ДСК Лизинг
#  615. OK 0.668 | Пазар Жилищни и ипотечни кредити
#  616. OK 0.287 | Други
#  617. OK 0.730 | Пазар Ежедневно банкиране
#  618. OK 0.578 | Пазар Потребителско кредитиране
#  619. OK 0.633 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
#  620. OK 0.484 | Пазар Жилищни и ипотечни кредити
#  621. OK 0.706 | Пазар Жилищни и ипотечни кредити
#  622. NOT OK 0.455 | Други
#        Expected: Пазар Ежедневно банкиране
#  623. OK 0.633 | Пазар Ежедневно банкиране
#  624. OK 0.535 | Пазар Ежедневно банкиране
#  625. OK 0.296 | Други
#  626. OK 0.647 | Други
#  627. OK 0.670 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
#  628. OK 0.377 | Други
#  629. OK 0.768 | Пазар Ежедневно банкиране
#  630. OK 0.649 | Пазар Ежедневно банкиране
#  631. OK 0.456 | Други
#  632. OK 0.799 | Пазар Ежедневно банкиране
#  633. OK 0.674 | Пазар Разсрочени плащания
#  634. OK 0.523 | Пазар Спестяване и инвестиции
#  635. OK 0.738 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
#  636. OK 0.469 | Други
#  637. OK 0.734 | Пазар Потребителско кредитиране
#  638. OK 0.659 | Пазар Разсрочени плащания
#  639. OK 0.622 | ДИРЕКЦИЯ КРЕДИТЕН РИСК ИНДИВИДУАЛНИ КЛИЕНТИ
#  640. OK 0.301 | Други
#  641. OK 0.796 | Пазар Ежедневно банкиране
#  642. OK 0.350 | Други
#  643. OK 0.325 | Други
#  644. OK 0.498 | Пазар Малък бизнес
#  645. OK 0.559 | Пазар Спестяване и инвестиции
#  646. OK 0.602 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  647. OK 0.294 | Други
#  648. OK 0.736 | Пазар Разсрочени плащания
#  649. OK 0.580 | Пазар Разсрочени плащания
#  650. OK 0.628 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  651. OK 0.872 | Пазар Ежедневно банкиране
#  652. NOT OK 0.387 | Support_Services
#        Expected: ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
#  653. OK 0.565 | Пазар Жилищни и ипотечни кредити
#  654. OK 0.521 | Няколко пазара
#  655. OK 0.691 | Други
#  656. OK 0.799 | Пазар Потребителско кредитиране
#  657. OK 0.629 | Пазар Ежедневно банкиране
#  658. OK 0.770 | Пазар Жилищни и ипотечни кредити
#  659. OK 0.657 | Пазар Ежедневно банкиране
#  660. OK 0.687 | Пазар Ежедневно банкиране
#  661. OK 0.582 | Пазар Малък бизнес
#  662. OK 0.742 | Пазар Разсрочени плащания
#  663. OK 0.490 | Пазар Ежедневно банкиране
#  664. NOT OK 0.657 | Support_Services
#        Expected: ПРАВНО
#  665. OK 0.763 | Пазар Жилищни и ипотечни кредити
#  666. NOT OK 0.238 | Други
#        Expected: Пазар Спестяване и инвестиции
#  667. OK 0.719 | Пазар Спестяване и инвестиции
#  668. OK 0.648 | Пазар Малък бизнес
#  669. OK 0.471 | Пазар Ежедневно банкиране
#  670. OK 0.606 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  671. NOT OK 0.397 | Support_Services
#        Expected: Пазар Ежедневно банкиране
#  672. OK 0.664 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
#  673. NOT OK 0.667 | Пазар Ежедневно банкиране
#        Expected: ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  674. OK 0.807 | Пазар Ежедневно банкиране
#  675. OK 0.837 | Пазар Ежедневно банкиране
#  676. OK 0.431 | Пазар Ежедневно банкиране
#  677. OK 0.830 | Пазар Потребителско кредитиране
#  678. OK 0.790 | Пазар Малък бизнес
#  679. OK 0.509 | Няколко пазара
#  680. OK 0.683 | Пазар Спестяване и инвестиции
#  681. OK 0.624 | Пазар Потребителско кредитиране
#  682. OK 0.624 | Пазар Ежедневно банкиране
#  683. OK 0.594 | Други
#  684. OK 0.835 | Пазар Ежедневно банкиране
#  685. OK 0.768 | Пазар Банково застраховане
#  686. OK 0.767 | Пазар Банково застраховане
#  687. OK 0.781 | Пазар Жилищни и ипотечни кредити
#  688. OK 0.600 | Пазар Ежедневно банкиране
#  689. OK 0.614 | Пазар Ежедневно банкиране
#  690. OK 0.592 | Пазар Ежедневно банкиране
#  691. OK 0.608 | Други
#  692. OK 0.788 | Пазар Банково застраховане
#  693. OK 0.480 | Други
#  694. OK 0.831 | Пазар Ежедневно банкиране
#  695. OK 0.597 | Пазар Ежедневно банкиране
#  696. OK 0.652 | Пазар Ежедневно банкиране
#  697. OK 0.285 | Пазар Ежедневно банкиране
#  698. OK 0.377 | Други
#  699. NOT OK 0.736 | Други
#        Expected: Пазар Банково застраховане
#  700. OK 0.718 | Пазар Спестяване и инвестиции
#  701. OK 0.780 | Пазар Жилищни и ипотечни кредити
#  702. OK 0.671 | Пазар Разсрочени плащания
#  703. OK 0.705 | Пазар Потребителско кредитиране
#  704. OK 0.350 | Други
#  705. OK 0.527 | Пазар Жилищни и ипотечни кредити
#  706. OK 0.683 | Няколко пазара
#  707. OK 0.565 | Няколко пазара
#  708. OK 0.558 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  709. OK 0.854 | Пазар Жилищни и ипотечни кредити
#  710. OK 0.706 | ДИРЕКЦИЯ КРЕДИТЕН РИСК ИНДИВИДУАЛНИ КЛИЕНТИ
#  711. OK 0.749 | Пазар Жилищни и ипотечни кредити
#  712. OK 0.706 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
#  713. OK 0.786 | Пазар Малък бизнес
#  714. OK 0.593 | Пазар Спестяване и инвестиции
#  715. OK 0.669 | Други
#  716. OK 0.611 | Пазар Потребителско кредитиране
#  717. OK 0.425 | Пазар Ежедневно банкиране
#  718. OK 0.688 | Пазар Потребителско кредитиране
#  719. OK 0.780 | Пазар Ежедневно банкиране
#  720. OK 0.583 | Пазар Спестяване и инвестиции
#  721. OK 0.471 | Други
#  722. OK 0.500 | Пазар Ежедневно банкиране
#  723. OK 0.213 | Пазар Ежедневно банкиране
#  724. OK 0.694 | Други
#  725. NOT OK 0.397 | Други
#        Expected: Пазар Ежедневно банкиране
#  726. OK 0.564 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  727. OK 0.574 | Други
#  728. OK 0.724 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  729. NOT OK 0.537 | Пазар Разсрочени плащания
#        Expected: ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  730. OK 0.811 | Пазар Малък бизнес
#  731. OK 0.355 | Пазар Ежедневно банкиране
#  732. OK 0.624 | Пазар Ежедневно банкиране
#  733. OK 0.736 | Пазар Малък бизнес
#  734. OK 0.730 | Пазар Малък бизнес
#  735. OK 0.439 | Други
#  736. OK 0.751 | Пазар Ежедневно банкиране
#  737. OK 0.630 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  738. OK 0.554 | Други
#  739. OK 0.823 | Пазар Потребителско кредитиране
#  740. OK 0.622 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
#  741. OK 0.833 | Пазар Ежедневно банкиране
#  742. OK 0.404 | Пазар Жилищни и ипотечни кредити
#  743. OK 0.552 | Други
#  744. OK 0.712 | Други
#  745. OK 0.541 | Пазар Спестяване и инвестиции
#  746. OK 0.674 | ДИРЕКЦИЯ КРЕДИТЕН РИСК ИНДИВИДУАЛНИ КЛИЕНТИ
#  747. OK 0.805 | Пазар Ежедневно банкиране
#  748. OK 0.564 | Пазар Банково застраховане
#  749. NOT OK 0.415 | Пазар Спестяване и инвестиции
#        Expected: Пазар Банково застраховане
#  750. OK 0.721 | Други
#  751. OK 0.574 | Пазар Жилищни и ипотечни кредити
#  752. OK 0.704 | Пазар Банково застраховане
#  753. OK 0.660 | Пазар Спестяване и инвестиции
#  754. OK 0.556 | Пазар Малък бизнес
#  755. OK 0.640 | Пазар Жилищни и ипотечни кредити
#  756. OK 0.532 | Пазар Ежедневно банкиране
#  757. OK 0.609 | Пазар Потребителско кредитиране
#  758. OK 0.786 | Пазар Банково застраховане
#  759. NOT OK 0.622 | Support_Services
#        Expected: ПРАВНО
#  760. OK 0.621 | Пазар Ежедневно банкиране
#  761. NOT OK 0.546 | Пазар Потребителско кредитиране
#        Expected: Няколко пазара
#  762. NOT OK 0.634 | Други
#        Expected: Пазар Ежедневно банкиране
#  763. OK 0.673 | Пазар Спестяване и инвестиции
#  764. OK 0.600 | Пазар Спестяване и инвестиции
#  765. OK 0.671 | Други
#  766. OK 0.555 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  767. OK 0.466 | Пазар Жилищни и ипотечни кредити
#  768. NOT OK 0.413 | Пазар Жилищни и ипотечни кредити
#        Expected: ПРАВНО
#  769. OK 0.757 | Пазар Ежедневно банкиране
#  770. OK 0.626 | Пазар Спестяване и инвестиции
#  771. OK 0.660 | Пазар Потребителско кредитиране
#  772. OK 0.445 | Пазар Банково застраховане
#  773. NOT OK 0.325 | Пазар Ежедневно банкиране
#        Expected: Други
#  774. OK 0.637 | Пазар Ежедневно банкиране
#  775. OK 0.694 | Пазар Потребителско кредитиране
#  776. OK 0.701 | Пазар Спестяване и инвестиции
#  777. NOT OK 0.329 | Support_Services
#        Expected: Други
#  778. OK 0.427 | Пазар Ежедневно банкиране
#  779. OK 0.337 | Други
#  780. OK 0.666 | ДИРЕКЦИЯ КРЕДИТЕН РИСК ИНДИВИДУАЛНИ КЛИЕНТИ
#  781. OK 0.546 | Други
#  782. OK 0.625 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  783. OK 0.784 | Пазар Малък бизнес
#  784. OK 0.438 | Пазар Ежедневно банкиране
#  785. OK 0.364 | Пазар Ежедневно банкиране
#  786. OK 0.507 | Пазар Ежедневно банкиране
#  787. OK 0.550 | Други
#  788. OK 0.548 | Пазар Жилищни и ипотечни кредити
#  789. OK 0.279 | Пазар Ежедневно банкиране
#  790. NOT OK 0.489 | Пазар Ежедневно банкиране
#        Expected: Пазар Малък бизнес
#  791. OK 0.782 | Пазар Жилищни и ипотечни кредити
#  792. OK 0.831 | Пазар Ежедневно банкиране
#  793. NOT OK 0.287 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
#        Expected: Други
#  794. OK 0.788 | Пазар Ежедневно банкиране
#  795. OK 0.371 | Други
#  796. OK 0.408 | Други
#  797. NOT OK 0.428 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
#        Expected: ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  798. OK 0.728 | Други
#  799. OK 0.668 | Пазар Жилищни и ипотечни кредити
#  800. OK 0.802 | Пазар Малък бизнес
#  801. OK 0.744 | Пазар Ежедневно банкиране
#  802. OK 0.756 | Пазар Малък бизнес
#  803. OK 0.606 | Пазар Спестяване и инвестиции
#  804. OK 0.609 | Пазар Малък бизнес
#  805. OK 0.561 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  806. OK 0.433 | Пазар Ежедневно банкиране
#  807. OK 0.803 | Пазар Ежедневно банкиране
#  808. OK 0.563 | Пазар Ежедневно банкиране
#  809. OK 0.726 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  810. NOT OK 0.192 | Пазар Малък бизнес
#        Expected: Пазар Ежедневно банкиране
#  811. OK 0.630 | Други
#  812. NOT OK 0.382 | Няколко пазара
#        Expected: Пазар Ежедневно банкиране
#  813. OK 0.510 | Пазар Ежедневно банкиране
#  814. OK 0.782 | Пазар Жилищни и ипотечни кредити
#  815. OK 0.544 | Други
#  816. OK 0.771 | Пазар Ежедневно банкиране
#  817. OK 0.762 | Пазар Ежедневно банкиране
#  818. NOT OK 0.640 | Support_Services
#        Expected: ПРАВНО
#  819. NOT OK 0.487 | Пазар Разсрочени плащания
#        Expected: Други
#  820. OK 0.586 | Пазар Ежедневно банкиране
#  821. OK 0.750 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
#  822. OK 0.556 | Пазар Потребителско кредитиране
#  823. NOT OK 0.227 | Пазар Жилищни и ипотечни кредити
#        Expected: Няколко пазара
#  824. OK 0.360 | Други
#  825. OK 0.489 | Други
#  826. OK 0.556 | Други
#  827. OK 0.757 | Пазар Ежедневно банкиране
#  828. OK 0.679 | Други
#  829. OK 0.468 | Няколко пазара
#  830. OK 0.548 | Пазар Ежедневно банкиране
#  831. OK 0.673 | Пазар Ежедневно банкиране
#  832. OK 0.824 | Пазар Жилищни и ипотечни кредити
#  833. OK 0.561 | Други
#  834. OK 0.559 | Пазар Ежедневно банкиране
#  835. OK 0.721 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
#  836. OK 0.674 | Пазар Разсрочени плащания
#  837. NOT OK 0.565 | Други
#        Expected: Пазар Ежедневно банкиране
#  838. OK 0.664 | Пазар Разсрочени плащания
#  839. NOT OK 0.426 | Пазар Ежедневно банкиране
#        Expected: ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  840. OK 0.667 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
#  841. OK 0.751 | Пазар Банково застраховане
#  842. OK 0.734 | Пазар Ежедневно банкиране
#  843. OK 0.607 | Пазар Ежедневно банкиране
#  844. OK 0.745 | Пазар Разсрочени плащания
#  845. OK 0.670 | Пазар Жилищни и ипотечни кредити
#  846. OK 0.752 | Пазар Ежедневно банкиране
#  847. OK 0.648 | Пазар Потребителско кредитиране
#  848. OK 0.630 | Пазар Разсрочени плащания
#  849. OK 0.761 | Пазар Потребителско кредитиране
#  850. OK 0.842 | Пазар Жилищни и ипотечни кредити
#  851. OK 0.427 | Други
#  852. OK 0.578 | Пазар Потребителско кредитиране
#  853. OK 0.601 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  854. OK 0.781 | Пазар Малък бизнес
#  855. OK 0.474 | Пазар Жилищни и ипотечни кредити
#  856. OK 0.731 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  857. OK 0.814 | Пазар Потребителско кредитиране
#  858. OK 0.678 | Пазар Разсрочени плащания
#  859. OK 0.565 | Пазар Ежедневно банкиране
#  860. OK 0.724 | Пазар Спестяване и инвестиции
#  861. OK 0.638 | Пазар Жилищни и ипотечни кредити
#  862. OK 0.721 | Пазар Малък бизнес
#  863. NOT OK 0.300 | Пазар Жилищни и ипотечни кредити
#        Expected: Други
#  864. OK 0.632 | Пазар Потребителско кредитиране
#  865. OK 0.544 | Пазар Ежедневно банкиране
#  866. OK 0.269 | Пазар Ежедневно банкиране
#  867. OK 0.693 | Пазар Ежедневно банкиране
#  868. NOT OK 0.680 | Support_Services
#        Expected: CRM
#  869. OK 0.765 | Пазар Банково застраховане
#  870. OK 0.695 | Пазар Потребителско кредитиране
#  871. OK 0.670 | Пазар Спестяване и инвестиции
#  872. OK 0.677 | Други
#  873. OK 0.616 | Други
#  874. OK 0.615 | Пазар Разсрочени плащания
#  875. OK 0.725 | Пазар Малък бизнес
#  876. OK 0.571 | Пазар Разсрочени плащания
#  877. OK 0.744 | Пазар Ежедневно банкиране
#  878. NOT OK 0.394 | Пазар Ежедневно банкиране
#        Expected: ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  879. OK 0.645 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  880. OK 0.520 | Пазар Ежедневно банкиране
#  881. OK 0.624 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  882. OK 0.370 | Пазар Ежедневно банкиране
#  883. OK 0.592 | Пазар Малък бизнес
#  884. OK 0.504 | Други
#  885. NOT OK 0.513 | Support_Services
#        Expected: ПРАВНО
#  886. OK 0.773 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  887. OK 0.691 | Пазар Потребителско кредитиране
#  888. OK 0.615 | Пазар Ежедневно банкиране
#  889. OK 0.296 | Пазар Ежедневно банкиране
#  890. OK 0.470 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
#  891. OK 0.267 | Пазар Спестяване и инвестиции
#  892. OK 0.417 | Пазар Ежедневно банкиране
#  893. NOT OK 0.363 | Пазар Ежедневно банкиране
#        Expected: Други
#  894. OK 0.663 | Няколко пазара
#  895. OK 0.398 | Пазар Ежедневно банкиране
#  896. OK 0.807 | Пазар Жилищни и ипотечни кредити
#  897. OK 0.816 | Пазар Ежедневно банкиране
#  898. OK 0.398 | Пазар Потребителско кредитиране
#  899. OK 0.755 | Пазар Жилищни и ипотечни кредити
#  900. OK 0.879 | Пазар Жилищни и ипотечни кредити
#  901. NOT OK 0.252 | Няколко пазара
#        Expected: Пазар Жилищни и ипотечни кредити
#  902. OK 0.686 | Пазар Ежедневно банкиране
#  903. OK 0.690 | Пазар Разсрочени плащания
#  904. OK 0.428 | Пазар Ежедневно банкиране
#  905. OK 0.604 | Други
#  906. OK 0.782 | Пазар Банково застраховане
#  907. NOT OK 0.355 | Пазар Спестяване и инвестиции
#        Expected: Други
#  908. OK 0.785 | Пазар Малък бизнес
#  909. OK 0.856 | Пазар Ежедневно банкиране
#  910. NOT OK 0.425 | Support_Services
#        Expected: CRM
#  911. OK 0.741 | Пазар Разсрочени плащания
#  912. OK 0.797 | Пазар Ежедневно банкиране
#  913. NOT OK 0.638 | Support_Services
#        Expected: ПРАВНО
#  914. OK 0.760 | Пазар Ежедневно банкиране
#  915. OK 0.594 | Пазар Ежедневно банкиране
#  916. OK 0.813 | Пазар Жилищни и ипотечни кредити
#  917. OK 0.617 | Пазар Разсрочени плащания
#  918. OK 0.771 | Други
#  919. OK 0.594 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  920. OK 0.492 | Пазар Разсрочени плащания
#  921. OK 0.406 | Пазар Ежедневно банкиране
#  922. OK 0.689 | Пазар Потребителско кредитиране
#  923. OK 0.642 | Пазар Ежедневно банкиране
#  924. OK 0.578 | Няколко пазара
#  925. OK 0.558 | Пазар Ежедневно банкиране
#  926. OK 0.295 | Други
#  927. OK 0.690 | Пазар Потребителско кредитиране
#  928. OK 0.544 | Други
#  929. OK 0.714 | Пазар Ежедневно банкиране
#  930. NOT OK 0.645 | Support_Services
#        Expected: ПРАВНО
#  931. OK 0.700 | Други
#  932. OK 0.746 | Пазар Малък бизнес
#  933. OK 0.634 | ДИРЕКЦИЯ КРЕДИТЕН РИСК ИНДИВИДУАЛНИ КЛИЕНТИ
#  934. OK 0.531 | Други
#  935. OK 0.753 | Други
#  936. OK 0.548 | Пазар Ежедневно банкиране
#  937. OK 0.781 | Пазар Ежедневно банкиране
#  938. OK 0.661 | Пазар Потребителско кредитиране
#  939. OK 0.720 | Пазар Спестяване и инвестиции
#  940. OK 0.699 | Пазар Ежедневно банкиране
#  941. OK 0.584 | Пазар Жилищни и ипотечни кредити
#  942. OK 0.611 | Пазар Жилищни и ипотечни кредити
#  943. OK 0.669 | Пазар Жилищни и ипотечни кредити
#  944. OK 0.645 | Пазар Жилищни и ипотечни кредити
#  945. OK 0.666 | Няколко пазара
#  946. OK 0.761 | Пазар Ежедневно банкиране
#  947. OK 0.604 | Пазар Ежедневно банкиране
#  948. OK 0.395 | Няколко пазара
#  949. OK 0.696 | Пазар Жилищни и ипотечни кредити
#  950. OK 0.669 | Пазар Жилищни и ипотечни кредити
#  951. OK 0.568 | Други
#  952. OK 0.583 | Пазар Ежедневно банкиране
#  953. OK 0.534 | Пазар Ежедневно банкиране
#  954. OK 0.599 | Пазар Ежедневно банкиране
#  955. OK 0.587 | Пазар Ежедневно банкиране
#  956. OK 0.316 | Пазар Ежедневно банкиране
#  957. OK 0.762 | Пазар Потребителско кредитиране
#  958. OK 0.350 | Други
#  959. NOT OK 0.426 | Support_Services
#        Expected: ПРАВНО
#  960. OK 0.441 | Пазар Ежедневно банкиране
#  961. OK 0.566 | Пазар Жилищни и ипотечни кредити
#  962. OK 0.724 | Пазар Ежедневно банкиране
#  963. OK 0.716 | Пазар Ежедневно банкиране
#  964. OK 0.336 | Други
#  965. OK 0.558 | Други
#  966. NOT OK 0.579 | Други
#        Expected: ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
#  967. OK 0.282 | Пазар Ежедневно банкиране
#  968. OK 0.500 | Други
#  969. OK 0.580 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
#  970. OK 0.789 | Пазар Потребителско кредитиране
#  971. OK 0.315 | Пазар Ежедневно банкиране
#  972. OK 0.371 | Други
#  973. OK 0.512 | Други
#  974. OK 0.547 | Други
#  975. OK 0.688 | Пазар Малък бизнес
#  976. OK 0.891 | Пазар Ежедневно банкиране
#  977. OK 0.458 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#  978. OK 0.780 | Пазар Разсрочени плащания
#  979. NOT OK 0.314 | Пазар Жилищни и ипотечни кредити
#        Expected: ПРАВНО
#  980. OK 0.600 | Други
#  981. NOT OK 0.698 | Пазар Разсрочени плащания
#        Expected: Други
#  982. NOT OK 0.377 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
#        Expected: Пазар Ежедневно банкиране
#  983. NOT OK 0.270 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#        Expected: Други
#  984. OK 0.375 | Пазар Потребителско кредитиране
#  985. OK 0.593 | Пазар Ежедневно банкиране
#  986. OK 0.445 | Пазар Ежедневно банкиране
#  987. OK 0.579 | Пазар Жилищни и ипотечни кредити
#  988. OK 0.541 | Пазар Ежедневно банкиране
#  989. OK 0.865 | Пазар Жилищни и ипотечни кредити
#  990. OK 0.478 | Пазар Ежедневно банкиране
#  991. OK 0.600 | Пазар Ежедневно банкиране
#  992. OK 0.572 | Пазар Потребителско кредитиране
#  993. OK 0.594 | Пазар Ежедневно банкиране
#  994. OK 0.312 | Пазар Ежедневно банкиране
#  995. OK 0.507 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
#  996. OK 0.555 | Пазар Ежедневно банкиране
#  997. OK 0.349 | Други
#  998. OK 0.577 | Пазар Ежедневно банкиране
#  999. OK 0.667 | Други
# 1000. OK 0.534 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
# 1001. OK 0.463 | Пазар Ежедневно банкиране
# 1002. NOT OK 0.368 | Support_Services
#        Expected: Пазар Ежедневно банкиране
# 1003. OK 0.435 | Пазар Потребителско кредитиране
# 1004. OK 0.572 | Пазар Ежедневно банкиране
# 1005. OK 0.561 | Пазар Малък бизнес
# 1006. OK 0.622 | Пазар Жилищни и ипотечни кредити
# 1007. OK 0.454 | Други
# 1008. OK 0.328 | Пазар Ежедневно банкиране
# 1009. OK 0.628 | Пазар Потребителско кредитиране
# 1010. OK 0.627 | Пазар Спестяване и инвестиции
# 1011. OK 0.774 | Пазар Разсрочени плащания
# 1012. OK 0.651 | Пазар Жилищни и ипотечни кредити
# 1013. OK 0.425 | Пазар Потребителско кредитиране
# 1014. OK 0.760 | Пазар Жилищни и ипотечни кредити
# 1015. OK 0.717 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
# 1016. OK 0.727 | Пазар Малък бизнес
# 1017. OK 0.581 | Пазар Жилищни и ипотечни кредити
# 1018. OK 0.472 | Други
# 1019. OK 0.527 | Пазар Ежедневно банкиране
# 1020. OK 0.772 | Пазар Спестяване и инвестиции
# 1021. OK 0.570 | Други
# 1022. OK 0.605 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
# 1023. OK 0.350 | Други
# 1024. OK 0.500 | Няколко пазара
# 1025. OK 0.741 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
# 1026. OK 0.600 | Други
# 1027. OK 0.741 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
# 1028. OK 0.759 | Пазар Банково застраховане
# 1029. OK 0.687 | Пазар Ежедневно банкиране
# 1030. OK 0.807 | Пазар Жилищни и ипотечни кредити
# 1031. OK 0.684 | Пазар Жилищни и ипотечни кредити
# 1032. OK 0.600 | Пазар Ежедневно банкиране
# 1033. OK 0.543 | Пазар Потребителско кредитиране
# 1034. OK 0.770 | Пазар Спестяване и инвестиции
# 1035. OK 0.682 | Други
# 1036. OK 0.720 | Пазар Ежедневно банкиране
# 1037. OK 0.570 | Пазар Малък бизнес
# 1038. OK 0.785 | Пазар Малък бизнес
# 1039. NOT OK 0.610 | Support_Services
#        Expected: ПРАВНО
# 1040. OK 0.632 | Пазар Ежедневно банкиране
# 1041. OK 0.738 | Няколко пазара
# 1042. OK 0.704 | Други
# 1043. OK 0.386 | Пазар Спестяване и инвестиции
# 1044. OK 0.530 | Други
# 1045. NOT OK 0.329 | Пазар Ежедневно банкиране
#        Expected: Други
# 1046. OK 0.762 | Пазар Ежедневно банкиране
# 1047. OK 0.733 | Пазар Ежедневно банкиране
# 1048. OK 0.588 | Пазар Разсрочени плащания
# 1049. OK 0.565 | Пазар Ежедневно банкиране
# 1050. OK 0.626 | ДИРЕКЦИЯ КРЕДИТЕН РИСК ИНДИВИДУАЛНИ КЛИЕНТИ
# 1051. OK 0.504 | Пазар Потребителско кредитиране
# 1052. OK 0.670 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
# ...
# 1627. OK 0.821 | Пазар Ежедневно банкиране
# 1628. OK 0.629 | Пазар Потребителско кредитиране
# 1629. NOT OK 0.343 | Няколко пазара
#        Expected: Пазар Жилищни и ипотечни кредити
# 1630. OK 0.555 | Други
# 1631. NOT OK 0.536 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
#        Expected: Пазар Ежедневно банкиране
# 1632. OK 0.530 | Пазар Спестяване и инвестиции
# 1633. OK 0.350 | Други
# 1634. OK 0.612 | Пазар Ежедневно банкиране
# 1635. OK 0.742 | Пазар Ежедневно банкиране
# 1636. NOT OK 0.519 | Пазар Разсрочени плащания
#        Expected: Пазар Ежедневно банкиране
# 1637. OK 0.734 | Пазар Потребителско кредитиране
# 1638. OK 0.640 | Пазар Жилищни и ипотечни кредити
# 1639. OK 0.638 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
# 1640. NOT OK 0.639 | Support_Services
#        Expected: ПРАВНО
# 1641. OK 0.763 | Пазар Жилищни и ипотечни кредити
# 1642. OK 0.404 | Пазар Ежедневно банкиране
# 1643. NOT OK 0.340 | Други
#        Expected: ПРАВНО
# 1644. OK 0.667 | Пазар Ежедневно банкиране
# 1645. OK 0.691 | Други
# 1646. OK 0.705 | Пазар Ежедневно банкиране
# 1647. OK 0.689 | Пазар Потребителско кредитиране
# 1648. OK 0.561 | Други
# 1649. OK 0.610 | Други
# 1650. NOT OK 0.394 | Пазар Жилищни и ипотечни кредити
#        Expected: Няколко пазара
# 1651. OK 0.721 | Други
# 1652. OK 0.450 | Няколко пазара
# 1653. OK 0.604 | Пазар Жилищни и ипотечни кредити
# 1654. NOT OK 0.450 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#        Expected: Други
# 1655. OK 0.630 | Други
# 1656. OK 0.587 | Други
# 1657. OK 0.597 | Пазар Жилищни и ипотечни кредити
# 1658. OK 0.720 | Пазар Разсрочени плащания
# 1659. OK 0.690 | Пазар Ежедневно банкиране
# 1660. NOT OK 0.403 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#        Expected: Пазар Ежедневно банкиране
# 1661. NOT OK 0.271 | Пазар Ежедневно банкиране
#        Expected: ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
# 1662. OK 0.645 | Пазар Жилищни и ипотечни кредити
# 1663. OK 0.728 | Пазар Банково застраховане
# 1664. OK 0.657 | Други
# 1665. OK 0.582 | Пазар Разсрочени плащания
# 1666. OK 0.264 | Пазар Ежедневно банкиране
# 1667. OK 0.778 | Пазар Жилищни и ипотечни кредити
# 1668. OK 0.460 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
# 1669. OK 0.772 | Пазар Ежедневно банкиране
# 1670. OK 0.680 | Пазар Потребителско кредитиране
# 1671. OK 0.765 | Пазар Жилищни и ипотечни кредити
# 1672. OK 0.780 | Пазар Ежедневно банкиране
# 1673. OK 0.776 | Пазар Малък бизнес
# 1674. OK 0.844 | Пазар Жилищни и ипотечни кредити
# 1675. NOT OK 0.217 | Пазар Жилищни и ипотечни кредити
#        Expected: Други
# 1676. OK 0.779 | Пазар Ежедневно банкиране
# 1677. NOT OK 0.667 | Support_Services
#        Expected: ПРАВНО
# 1678. OK 0.786 | Други
# 1679. OK 0.553 | Няколко пазара
# 1680. OK 0.608 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
# 1681. OK 0.807 | Пазар Разсрочени плащания
# 1682. OK 0.457 | Други
# 1683. OK 0.368 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
# 1684. OK 0.697 | Пазар Ежедневно банкиране
# 1685. OK 0.697 | Пазар Потребителско кредитиране
# 1686. OK 0.624 | Пазар Жилищни и ипотечни кредити
# 1687. OK 0.421 | Пазар Жилищни и ипотечни кредити
# 1688. OK 0.495 | Пазар Малък бизнес
# 1689. OK 0.611 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
# 1690. OK 0.554 | Други
# 1691. OK 0.662 | Пазар Ежедневно банкиране
# 1692. OK 0.691 | Пазар Спестяване и инвестиции
# 1693. OK 0.772 | Пазар Ежедневно банкиране
# 1694. OK 0.870 | Пазар Жилищни и ипотечни кредити
# 1695. OK 0.889 | Пазар Жилищни и ипотечни кредити
# 1696. OK 0.636 | Няколко пазара
# 1697. OK 0.661 | Пазар Потребителско кредитиране
# 1698. OK 0.807 | Пазар Разсрочени плащания
# 1699. OK 0.350 | Други
# 1700. OK 0.341 | Пазар Ежедневно банкиране
# 1701. OK 0.329 | Пазар Ежедневно банкиране
# 1702. OK 0.441 | Пазар Жилищни и ипотечни кредити
# 1703. OK 0.697 | Други
# 1704. OK 0.570 | Други
# 1705. OK 0.680 | Пазар Потребителско кредитиране
# 1706. OK 0.554 | Пазар Ежедневно банкиране
# 1707. OK 0.729 | Други
# 1708. OK 0.456 | Други
# 1709. OK 0.660 | Други
# 1710. OK 0.778 | Пазар Жилищни и ипотечни кредити
# 1711. NOT OK 0.267 | Пазар Ежедневно банкиране
#        Expected: Други
# 1712. OK 0.770 | Други
# 1713. OK 0.460 | Други
# 1714. OK 0.675 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
# 1715. OK 0.414 | Пазар Ежедневно банкиране
# 1716. OK 0.670 | Пазар Спестяване и инвестиции
# 1717. OK 0.561 | ДИРЕКЦИЯ КРЕДИТЕН РИСК ИНДИВИДУАЛНИ КЛИЕНТИ
# 1718. NOT OK 0.292 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#        Expected: Пазар Ежедневно банкиране
# 1719. OK 0.838 | Пазар Банково застраховане
# 1720. OK 0.587 | Пазар Ежедневно банкиране
# 1721. OK 0.615 | Други
# 1722. OK 0.548 | Пазар Ежедневно банкиране
# 1723. OK 0.665 | Пазар Ежедневно банкиране
# 1724. NOT OK 0.524 | Пазар Разсрочени плащания
#        Expected: Пазар Ежедневно банкиране
# 1725. NOT OK 0.331 | Други
#        Expected: Пазар Ежедневно банкиране
# 1726. OK 0.599 | Други
# 1727. OK 0.726 | Други
# 1728. OK 0.626 | Пазар Жилищни и ипотечни кредити
# 1729. OK 0.602 | Пазар Жилищни и ипотечни кредити
# 1730. OK 0.458 | Пазар Спестяване и инвестиции
# 1731. OK 0.640 | Пазар Ежедневно банкиране
# 1732. OK 0.726 | Други
# 1733. OK 0.567 | Няколко пазара
# 1734. OK 0.761 | Пазар Малък бизнес
# 1735. OK 0.593 | Пазар Спестяване и инвестиции
# 1736. OK 0.474 | Пазар Потребителско кредитиране
# 1737. OK 0.756 | Пазар Банково застраховане
# 1738. OK 0.694 | Пазар Жилищни и ипотечни кредити
# 1739. OK 0.673 | Пазар Разсрочени плащания
# 1740. NOT OK 0.224 | Пазар Ежедневно банкиране
#        Expected: Други
# 1741. OK 0.663 | Пазар Жилищни и ипотечни кредити
# 1742. OK 0.760 | Пазар Ежедневно банкиране
# 1743. NOT OK 0.377 | Пазар Ежедневно банкиране
#        Expected: Други
# 1744. OK 0.583 | Пазар Ежедневно банкиране
# 1745. OK 0.710 | Пазар Ежедневно банкиране
# 1746. NOT OK 0.400 | Пазар Спестяване и инвестиции
#        Expected: Други
# 1747. OK 0.819 | Пазар Ежедневно банкиране
# 1748. OK 0.752 | Пазар Жилищни и ипотечни кредити
# 1749. OK 0.588 | Няколко пазара
# 1750. OK 0.658 | ДИРЕКЦИЯ КРЕДИТЕН РИСК ИНДИВИДУАЛНИ КЛИЕНТИ
# 1751. OK 0.672 | Пазар Ежедневно банкиране
# 1752. OK 0.693 | Други
# 1753. OK 0.691 | Пазар Потребителско кредитиране
# 1754. OK 0.725 | Пазар Спестяване и инвестиции
# 1755. NOT OK 0.310 | Няколко пазара
#        Expected: Други
# 1756. OK 0.458 | Други
# 1757. OK 0.453 | Пазар Разсрочени плащания
# 1758. OK 0.574 | Пазар Ежедневно банкиране
# 1759. OK 0.480 | Пазар Ежедневно банкиране
# 1760. OK 0.672 | Пазар Потребителско кредитиране
# 1761. OK 0.654 | Пазар Ежедневно банкиране
# 1762. OK 0.651 | Други
# 1763. OK 0.738 | Пазар Потребителско кредитиране
# 1764. OK 0.524 | Пазар Жилищни и ипотечни кредити
# 1765. OK 0.597 | Пазар Банково застраховане
# 1766. OK 0.564 | Пазар Малък бизнес
# 1767. OK 0.631 | Пазар Жилищни и ипотечни кредити
# 1768. OK 0.750 | Пазар Разсрочени плащания
# 1769. OK 0.594 | Пазар Потребителско кредитиране
# 1770. OK 0.646 | ДИРЕКЦИЯ КРЕДИТЕН РИСК ИНДИВИДУАЛНИ КЛИЕНТИ
# 1771. OK 0.574 | Няколко пазара
# 1772. NOT OK 0.390 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#        Expected: Пазар Ежедневно банкиране
# 1773. OK 0.263 | Пазар Ежедневно банкиране
# 1774. OK 0.761 | Пазар Жилищни и ипотечни кредити
# 1775. OK 0.683 | Други
# 1776. OK 0.819 | Пазар Банково застраховане
# 1777. OK 0.819 | Пазар Жилищни и ипотечни кредити
# 1778. OK 0.622 | Пазар Жилищни и ипотечни кредити
# 1779. NOT OK 0.621 | ДИРЕКЦИЯ КРЕДИТЕН РИСК ИНДИВИДУАЛНИ КЛИЕНТИ
#        Expected: Няколко пазара
# 1780. OK 0.546 | Пазар Малък бизнес
# 1781. OK 0.519 | Пазар Малък бизнес
# 1782. OK 0.724 | Пазар Потребителско кредитиране
# 1783. OK 0.706 | Пазар Ежедневно банкиране
# 1784. OK 0.694 | Пазар Ежедневно банкиране
# 1785. OK 0.595 | Пазар Ежедневно банкиране
# 1786. OK 0.556 | Пазар Потребителско кредитиране
# 1787. OK 0.606 | Пазар Банково застраховане
# 1788. OK 0.369 | Пазар Малък бизнес
# 1789. NOT OK 0.597 | Support_Services
#        Expected: ПРАВНО
# 1790. OK 0.414 | Други
# 1791. OK 0.740 | Пазар Жилищни и ипотечни кредити
# 1792. OK 0.597 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
# 1793. OK 0.718 | Пазар Банково застраховане
# 1794. OK 0.317 | Пазар Ежедневно банкиране
# 1795. OK 0.751 | Други
# 1796. OK 0.534 | Пазар Ежедневно банкиране
# 1797. OK 0.398 | Пазар Жилищни и ипотечни кредити
# 1798. NOT OK 0.325 | Няколко пазара
#        Expected: Пазар Ежедневно банкиране
# 1799. OK 0.796 | Пазар Разсрочени плащания
# 1800. OK 0.615 | Пазар Ежедневно банкиране
# 1801. OK 0.453 | Пазар Ежедневно банкиране
# 1802. OK 0.568 | Пазар Жилищни и ипотечни кредити
# 1803. OK 0.699 | Пазар Банково застраховане
# 1804. OK 0.481 | Други
# 1805. OK 0.767 | Пазар Ежедневно банкиране
# 1806. OK 0.585 | Други
# 1807. OK 0.613 | Няколко пазара
# 1808. OK 0.653 | Пазар Ежедневно банкиране
# 1809. NOT OK 0.770 | Пазар Жилищни и ипотечни кредити
#        Expected: Няколко пазара
# 1810. OK 0.694 | Пазар Ежедневно банкиране
# 1811. OK 0.642 | Други
# 1812. OK 0.808 | Пазар Жилищни и ипотечни кредити
# 1813. OK 0.631 | Пазар Ежедневно банкиране
# 1814. OK 0.742 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
# 1815. OK 0.753 | Други
# 1816. OK 0.616 | Пазар Малък бизнес
# 1817. OK 0.701 | Пазар Спестяване и инвестиции
# 1818. OK 0.699 | Пазар Жилищни и ипотечни кредити
# 1819. OK 0.770 | Пазар Банково застраховане
# 1820. OK 0.814 | Пазар Банково застраховане
# 1821. OK 0.475 | Пазар Банково застраховане
# 1822. NOT OK 0.271 | Пазар Ежедневно банкиране
#        Expected: Други
# 1823. OK 0.717 | Пазар Жилищни и ипотечни кредити
# 1824. NOT OK 0.219 | Пазар Спестяване и инвестиции
#        Expected: Пазар Ежедневно банкиране
# 1825. OK 0.827 | Пазар Жилищни и ипотечни кредити
# 1826. OK 0.777 | Пазар Жилищни и ипотечни кредити
# 1827. OK 0.277 | Пазар Ежедневно банкиране
# 1828. OK 0.802 | Пазар Ежедневно банкиране
# 1829. OK 0.598 | Пазар Жилищни и ипотечни кредити
# 1830. OK 0.258 | Пазар Жилищни и ипотечни кредити
# 1831. OK 0.779 | Пазар Ежедневно банкиране
# 1832. OK 0.673 | Пазар Ежедневно банкиране
# 1833. OK 0.782 | Пазар Спестяване и инвестиции
# 1834. OK 0.743 | Пазар Спестяване и инвестиции
# 1835. OK 0.825 | Пазар Ежедневно банкиране
# 1836. OK 0.556 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
# 1837. OK 0.333 | Пазар Ежедневно банкиране
# 1838. OK 0.397 | Други
# 1839. OK 0.768 | Пазар Ежедневно банкиране
# 1840. OK 0.527 | Няколко пазара
# 1841. OK 0.417 | Пазар Ежедневно банкиране
# 1842. OK 0.441 | Пазар Жилищни и ипотечни кредити
# 1843. NOT OK 0.273 | Пазар Ежедневно банкиране
#        Expected: Пазар Жилищни и ипотечни кредити
# 1844. OK 0.572 | Други
# 1845. OK 0.781 | Пазар Жилищни и ипотечни кредити
# 1846. OK 0.393 | Други
# 1847. OK 0.776 | Пазар Ежедневно банкиране
# 1848. OK 0.258 | Пазар Ежедневно банкиране
# 1849. OK 0.601 | Няколко пазара
# 1850. OK 0.733 | Пазар Потребителско кредитиране
# 1851. OK 0.598 | Пазар Жилищни и ипотечни кредити
# 1852. OK 0.645 | Пазар Жилищни и ипотечни кредити
# 1853. OK 0.733 | Пазар Спестяване и инвестиции
# 1854. OK 0.558 | Пазар Разсрочени плащания
# 1855. NOT OK 0.626 | Support_Services
#        Expected: CRM
# 1856. OK 0.767 | Пазар Ежедневно банкиране
# 1857. OK 0.812 | Пазар Ежедневно банкиране
# 1858. NOT OK 0.285 | Пазар Ежедневно банкиране
#        Expected: Пазар Малък бизнес
# 1859. OK 0.481 | Пазар Потребителско кредитиране
# 1860. OK 0.580 | Няколко пазара
# 1861. OK 0.491 | Пазар Ежедневно банкиране
# 1862. NOT OK 0.435 | Други
#        Expected: Няколко пазара
# 1863. NOT OK 0.437 | ДИРЕКЦИЯ БАНКОВИ ОПЕРАЦИИ
#        Expected: Пазар Ежедневно банкиране
# 1864. OK 0.611 | Пазар Спестяване и инвестиции
# 1865. NOT OK 0.388 | Пазар Ежедневно банкиране
#        Expected: ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
# 1866. OK 0.553 | Пазар Банково застраховане
# 1867. OK 0.350 | Други
# 1868. OK 0.801 | Пазар Банково застраховане
# 1869. OK 0.610 | Пазар Ежедневно банкиране
# 1870. OK 0.673 | Пазар Жилищни и ипотечни кредити
# 1871. OK 0.538 | Пазар Ежедневно банкиране
# 1872. OK 0.555 | Други
# 1873. OK 0.640 | Пазар Ежедневно банкиране
# 1874. NOT OK 0.622 | Support_Services
#        Expected: ПРАВНО
# 1875. OK 0.603 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
# 1876. OK 0.638 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
# 1877. OK 0.719 | Пазар Разсрочени плащания
# 1878. OK 0.792 | Пазар Ежедневно банкиране
# 1879. OK 0.825 | Пазар Разсрочени плащания
# 1880. NOT OK 0.472 | Пазар Ежедневно банкиране
#        Expected: Пазар Малък бизнес
# 1881. OK 0.679 | Други
# 1882. OK 0.415 | Други
# 1883. OK 0.714 | Пазар Жилищни и ипотечни кредити
# 1884. NOT OK 0.433 | Support_Services
#        Expected: ПРАВНО
# 1885. OK 0.702 | Пазар Жилищни и ипотечни кредити
# 1886. OK 0.667 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
# 1887. NOT OK 0.372 | Други
#        Expected: Пазар Ежедневно банкиране
# 1888. OK 0.696 | Няколко пазара
# 1889. OK 0.375 | Пазар Жилищни и ипотечни кредити
# 1890. OK 0.686 | Пазар Ежедневно банкиране
# 1891. OK 0.510 | Други
# 1892. OK 0.824 | Пазар Ежедневно банкиране
# 1893. OK 0.741 | Пазар Жилищни и ипотечни кредити
# 1894. OK 0.412 | Пазар Ежедневно банкиране
# 1895. OK 0.743 | Пазар Разсрочени плащания
# 1896. NOT OK 0.203 | Пазар Жилищни и ипотечни кредити
#        Expected: ДИРЕКЦИЯ КРЕДИТЕН РИСК ИНДИВИДУАЛНИ КЛИЕНТИ
# 1897. OK 0.732 | Пазар Ежедневно банкиране
# 1898. OK 0.299 | Пазар Ежедневно банкиране
# 1899. OK 0.735 | Други
# 1900. OK 0.618 | Пазар Потребителско кредитиране
# 1901. OK 0.380 | Пазар Жилищни и ипотечни кредити
# 1902. OK 0.316 | Пазар Ежедневно банкиране
# 1903. OK 0.729 | Пазар Ежедневно банкиране
# 1904. OK 0.317 | Други
# 1905. OK 0.391 | Пазар Разсрочени плащания
# 1906. OK 0.690 | Пазар Жилищни и ипотечни кредити
# 1907. OK 0.543 | Пазар Ежедневно банкиране
# 1908. NOT OK 0.282 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
#        Expected: Пазар Ежедневно банкиране
# 1909. OK 0.713 | Други
# 1910. OK 0.492 | Пазар Ежедневно банкиране
# 1911. OK 0.465 | Други
# 1912. NOT OK 0.233 | Други
#        Expected: Пазар Ежедневно банкиране
# 1913. OK 0.722 | Други
# 1914. OK 0.453 | Пазар Ежедневно банкиране
# 1915. OK 0.305 | Пазар Ежедневно банкиране
# 1916. OK 0.672 | Пазар Ежедневно банкиране
# 1917. OK 0.423 | Други
# 1918. NOT OK 0.197 | Други
#        Expected: Пазар Жилищни и ипотечни кредити
# 1919. OK 0.467 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
# 1920. OK 0.734 | Пазар Потребителско кредитиране
# 1921. OK 0.570 | Други
# 1922. OK 0.542 | Пазар Жилищни и ипотечни кредити
# 1923. OK 0.410 | Други
# 1924. OK 0.589 | Други
# 1925. OK 0.489 | Пазар Спестяване и инвестиции
# 1926. NOT OK 0.443 | Пазар Жилищни и ипотечни кредити
#        Expected: Няколко пазара
# 1927. OK 0.558 | Пазар Ежедневно банкиране
# 1928. OK 0.686 | Пазар Банково застраховане
# 1929. OK 0.816 | Пазар Ежедневно банкиране
# 1930. OK 0.615 | Пазар Ежедневно банкиране
# 1931. NOT OK 0.357 | Пазар Ежедневно банкиране
#        Expected: ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
# 1932. OK 0.715 | Пазар Разсрочени плащания
# 1933. OK 0.683 | Пазар Ежедневно банкиране
# 1934. OK 0.704 | Пазар Разсрочени плащания
# 1935. NOT OK 0.252 | Пазар Ежедневно банкиране
#        Expected: ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
# 1936. OK 0.544 | Пазар Жилищни и ипотечни кредити
# 1937. OK 0.298 | Пазар Ежедневно банкиране
# 1938. OK 0.788 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
# 1939. OK 0.660 | Пазар Жилищни и ипотечни кредити
# 1940. OK 0.790 | Пазар Ежедневно банкиране
# 1941. OK 0.447 | ДИРЕКЦИЯ ПАЗАР АТМ И КАСОВА ДЕЙНОСТ
# 1942. NOT OK 0.269 | Пазар Потребителско кредитиране
#        Expected: Пазар Ежедневно банкиране
# 1943. OK 0.589 | Пазар Ежедневно банкиране
# 1944. OK 0.809 | Пазар Банково застраховане
# 1945. OK 0.705 | Пазар Спестяване и инвестиции
# 1946. OK 0.580 | Пазар Жилищни и ипотечни кредити
# 1947. OK 0.782 | Пазар Жилищни и ипотечни кредити
# 1948. OK 0.367 | Пазар Спестяване и инвестиции
# 1949. OK 0.434 | Пазар Разсрочени плащания
# 1950. OK 0.381 | Пазар Ежедневно банкиране
# 1951. OK 0.530 | Пазар Ежедневно банкиране
# 1952. OK 0.679 | Пазар Жилищни и ипотечни кредити
# 1953. OK 0.423 | Пазар Ежедневно банкиране
# 1954. OK 0.500 | Пазар Ежедневно банкиране
# 1955. NOT OK 0.568 | Други
#        Expected: Пазар Жилищни и ипотечни кредити
# 1956. OK 0.855 | Пазар Ежедневно банкиране
# 1957. OK 0.202 | Пазар Жилищни и ипотечни кредити
# 1958. OK 0.551 | Други
# 1959. NOT OK 0.473 | ДИРЕКЦИЯ КРЕДИТЕН РИСК ИНДИВИДУАЛНИ КЛИЕНТИ
#        Expected: Пазар Жилищни и ипотечни кредити
# 1960. OK 0.735 | Пазар Малък бизнес
# 1961. OK 0.614 | Пазар Разсрочени плащания
# 1962. NOT OK 0.451 | Пазар Ежедневно банкиране
#        Expected: Други
#
# SUMMARY:
# Accuracy: 1738/1962 (88.6%)
# Avg Confidence: 0.593
#
# EXPORTING RESULTS TO EXCEL...
# Results exported to: ../models/model_test_results.xlsx
#    Sheet 1: Test Results (1962 rows)
#    Sheet 2: Summary Statistics
#    Sheet 3: Department Analysis
